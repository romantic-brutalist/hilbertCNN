# %%
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import numpy as np
from hilbert import decode, encode
import pandas as pd
from tqdm import tqdm
import torch
from comet_ml import Experiment

# Create an experiment with your api key
experiment = Experiment(
    api_key="uM0HPEvEu6OyX3dTEuB4Fihgz",
    project_name="hilbertcnn",
    workspace="romantic-brutalist",
)
# Out:
# <style>.container { width:100% !important; }</style>
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: torch. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/home/caliban/hilbertCNN' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/romantic-brutalist/hilbertcnn/2708dbfbb87947568582137621c1dde4

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
data = np.array(range(32*32))
data_val_1 = np.sin(np.arange(32*32) * np.pi / 128. ) + (np.random.rand()-0.5)
data_val_2 = np.sin(np.arange(32*32) * np.pi / 128. )

locs = decode(data, 2, 5)

print(locs)
# prints [[0 1]
#         [1 1]
#         [1 0]]

# You can go the other way also, of course.
H = encode(locs, 2, 5)

h1 = np.zeros((32,32))
h2 = np.zeros((32,32))

for i in range(len(data)):
    h1[locs[i][0],locs[i][1]] = data_val_1[i]
    h2[locs[i][0],locs[i][1]] = data_val_2[i]
# Out:
# [[ 0  0]
#  [ 0  1]
#  [ 1  1]
#  ...
#  [30  1]
#  [31  1]
#  [31  0]]

# %%
plt.imshow(np.abs(np.rot90(h2)))

# %%
start_time = 1569877200
end_time = 1664951851

# %%
times = np.arange(start=start_time,stop=end_time,step=60000)

# %%
times.shape
# Out:
# (1585,)

# %%
import requests
from tqdm import tqdm
import pandas as pd
cols=["OpenTime",
"Open",
"High",
"Low",
"Close",
"Volume",
"CloseTime",
"QuoteAsset",
"NumberOfTrades",
"TakerBuybaseassetvolume",
"TakerBuyquoteassetvolume",
"Ignore"]
dfl = []
market = 'BTCUSDT'
tick_interval = '1m'
for i in tqdm(range(len(times))):
    url = 'https://fapi.binance.com/fapi/v1/klines?symbol='+market+'&interval='+tick_interval+'&startTime='+str(times[i]*1000)+'&endTime='+str(times[i+1]*1000)+'&limit=1000'
    data = requests.get(url).json()
    dfl.append(pd.DataFrame(data,columns=cols))
# Out:
# 100%|██████████████████████████████████████▉| 1584/1585 [13:37<00:00,  1.94it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [184], in <cell line: 6>()
#       5 tick_interval = '1m'
#       6 for i in tqdm(range(len(times))):
# ----> 7     url = 'https://fapi.binance.com/fapi/v1/klines?symbol='+market+'&interval='+tick_interval+'&startTime='+str(times[i]*1000)+'&endTime='+str(times[i+1]*1000)+'&limit=1000'
#       8     data = requests.get(url).json()
#       9     dfl.append(pd.DataFrame(data,columns=cols))
#
# IndexError: index 1585 is out of bounds for axis 0 with size 1585

# %%
df = pd.concat(dfl)
df.OpenTime=pd.to_datetime(df["OpenTime"],unit="ms")+pd.DateOffset(hours=3)
df.to_parquet("F_BTCUSDT_1m.parquet")

# %%
df.to_parquet("F_BTCUSDT_1m.parquet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df.to_parquet("F_BTCUSDT_1m.parquet")
#       2 df = pd.read_parquet("F_BTCUSDT_1m.parquet")
#
# NameError: name 'df' is not defined

# %%
df = pd.read_parquet("data/F_BTCUSDT_1m.parquet")
tc = ["Open",
"High",
"Low",
"Close",
"Volume"]
for i in tc:
    df[i]=df[i].astype("float")

# %%
df.iloc[0:15].Close.max()
# Out:
# 8223.87

# %%
data = np.array(range(32*32))
locs = decode(data, 2, 5)
hilbert_list = []
target_list = []

for i in tqdm(range(32*32,len(df),10)):
    temp_f = df.iloc[i-32*32:i]
    temp_t_30 = df.iloc[i:i+30]
    temp_t_15 = df.iloc[i:i+15]
    
    lv = temp_f.Close.iloc[-1]
    o1 = np.zeros((4,32,32))
    vals = temp_f[["Open","High","Low","Close"]].values
    for j in range(len(data)):
        o1[:,locs[j][0],locs[j][1]] = vals[j]

    hilbert_list.append(o1)
    target_list.append(
        np.array([(temp_t_30.Low.min()/lv)-1,(temp_t_30.High.max()/lv)-1,(temp_t_15.Low.min()/lv)-1,(temp_t_15.High.max()/lv)-1])
    )
# Out:
# 100%|██████████████████████████████████| 158298/158298 [03:24<00:00, 773.76it/s]

# %%
temp_f
# Out:
#                 OpenTime     Open     High      Low    Close  Volume  \
# 0    2019-10-01 00:00:00  8209.67  8216.04  8209.22  8211.91   3.282
# 1    2019-10-01 00:01:00  8215.93  8216.90  8210.87  8215.00   2.821
# 2    2019-10-01 00:02:00  8215.00  8215.00  8213.00  8214.58   1.241
# 3    2019-10-01 00:03:00  8214.31  8215.00  8213.04  8214.72   0.548
# 4    2019-10-01 00:04:00  8214.72  8215.00  8214.72  8215.00   1.055
# ...                  ...      ...      ...      ...      ...     ...
# 1019 2019-10-01 16:59:00  8332.44  8343.50  8332.06  8341.00  14.973
# 1020 2019-10-01 17:00:00  8339.21  8341.00  8334.71  8339.07   2.617
# 1021 2019-10-01 17:01:00  8338.05  8349.40  8338.05  8347.44  49.038
# 1022 2019-10-01 17:02:00  8345.24  8347.00  8339.26  8347.00  35.059
# 1023 2019-10-01 17:03:00  8346.30  8356.73  8346.30  8354.78  35.390
#
#           CloseTime    QuoteAsset  NumberOfTrades TakerBuybaseassetvolume  \
# 0     1569877259999   26949.57673              33                   1.650
# 1     1569877319999   23173.71997              18                   2.711
# 2     1569877379999   10192.89112              27                   0.400
# 3     1569877439999    4501.69900              23                   0.361
# 4     1569877499999    8666.78673              17                   0.948
# ...             ...           ...             ...                     ...
# 1019  1569938399999  124870.82274              46                   7.723
# 1020  1569938459999   21818.85727              28                   1.755
# 1021  1569938519999  409312.90494              66                  46.484
# 1022  1569938579999  292454.25723              56                   3.535
# 1023  1569938639999  295624.36612             111                  28.074
#
#      TakerBuyquoteassetvolume Ignore
# 0                 13550.96373      0
# 1                 22270.40007      0
# 2                  3285.73147      0
# 3                  2965.55218      0
# 4                  7787.78280      0
# ...                       ...    ...
# 1019              64408.53068      0
# 1020              14629.84248      0
# 1021             388005.68968      0
# 1022              29499.04823      0
# 1023             234508.35585      0
#
# [1024 rows x 12 columns]

# %%
o1[3]
# Out:
# array([[8211.91, 8215.  , 8215.44, ..., 8373.19, 8370.  , 8375.71],
#        [8214.72, 8214.58, 8223.87, ..., 8367.25, 8377.53, 8376.48],
#        [8215.  , 8218.13, 8218.25, ..., 8381.93, 8369.3 , 8367.94],
#        ...,
#        [8341.  , 8333.54, 8334.15, ..., 8389.91, 8384.41, 8383.  ],
#        [8339.07, 8347.44, 8343.25, ..., 8364.03, 8377.09, 8377.  ],
#        [8354.78, 8347.  , 8345.07, ..., 8362.2 , 8369.91, 8369.99]])

# %%
target_df = pd.DataFrame(target_list,columns=["Low_30","High_30","Low_15","High_15"])

# %%
def mapper(x):
    if x==0:
        return np.array([0,0,0,1,0,0,0])
    elif (x<0.005) and (x>0.0):
        return np.array([0,0,0,0,1,0,0])
    elif (x<0.01) and (x>=0.005):
        return np.array([0,0,0,0,0,1,0])
    elif (x>=0.01):
        return np.array([0,0,0,0,0,0,1])
    elif (x>-0.005) and (x<0.0):
        return np.array([0,0,1,0,0,0,0])
    elif (x>-0.01) and (x<=-0.005):
        return np.array([0,1,0,0,0,0,0])
    elif (x<=-0.01):
        return np.array([1,0,0,0,0,0,0])

# %%
for i in target_df.columns:
    target_df[i] = target_df[i].apply(mapper)

# %%
target_df
# Out:
#           Low_30   High_30    Low_15   High_15
# 0      -0.005240  0.000674 -0.005240  0.000674
# 1      -0.001107  0.004586 -0.001107  0.003405
# 2      -0.003448  0.001991 -0.003334  0.001991
# 3      -0.003757  0.001949 -0.002360  0.001949
# 4      -0.002651  0.002441 -0.001563  0.002441
# ...          ...       ...       ...       ...
# 158293 -0.000580  0.011258 -0.000580  0.004813
# 158294 -0.001145  0.012076 -0.001145  0.007139
# 158295 -0.000286  0.009678 -0.000286  0.002980
# 158296 -0.001141  0.008595 -0.001141  0.008595
# 158297 -0.001910  0.000658 -0.001910  0.000658
#
# [158298 rows x 4 columns]

# %%
hlt = np.array(hilbert_list)

# %%
hlt = (hlt-hlt.mean())/hlt.std()

# %%
for i,j in enumerate(hlt):
    print(i,j.shape)
    if i==2:
        break
# Out:
# 0 (4, 32, 32)
# 1 (4, 32, 32)
# 2 (4, 32, 32)

# %%
div = int(len(hlt)*0.9)

# %%
div
# Out:
# 142468

# %%
for i,j in tqdm(enumerate(hlt)):
    if i<div:
        np.save('imgs/train_4layer/%07d.npy'%i,j)
    else:
        np.save('imgs/test_4layer/%07d.npy'%i,j)
# Out:
# 158298it [00:07, 20963.38it/s]

# %%
target_df

# %%
np.save("0001.npy",npl[0])

# %%
target_df["label"] = target_df.index.to_list()

# %%
target_df["label"] = target_df.label.apply(lambda x:"%07d.npy"%x)

# %%
target_df.iloc[:div].to_parquet("imgs/train_4layer/target.parquet")
target_df.iloc[div:].to_parquet("imgs/test_4layer/target.parquet")

# %%
tt = hilbert_list[0]

# %%
import torch

# %%
target_df
# Out:
#           Low_30   High_30    Low_15   High_15        label
# 0      -0.005240  0.000674 -0.005240  0.000674  0000000.npy
# 1      -0.001107  0.004586 -0.001107  0.003405  0000001.npy
# 2      -0.003448  0.001991 -0.003334  0.001991  0000002.npy
# 3      -0.003757  0.001949 -0.002360  0.001949  0000003.npy
# 4      -0.002651  0.002441 -0.001563  0.002441  0000004.npy
# ...          ...       ...       ...       ...          ...
# 158293 -0.000580  0.011258 -0.000580  0.004813  0158293.npy
# 158294 -0.001145  0.012076 -0.001145  0.007139  0158294.npy
# 158295 -0.000286  0.009678 -0.000286  0.002980  0158295.npy
# 158296 -0.001141  0.008595 -0.001141  0.008595  0158296.npy
# 158297 -0.001910  0.000658 -0.001910  0.000658  0158297.npy
#
# [158298 rows x 5 columns]

# %%
import os
import pandas as pd
from torchvision.io import read_image
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
class HilbertImageDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_dir = img_dir
        self.img_labels = pd.read_parquet(os.path.join(self.img_dir, annotations_file))
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, -1])
        image = np.load(img_path)
        label = self.img_labels.iloc[idx, :-1].values.astype("float64")
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
train_ds = HilbertImageDataset(annotations_file="target.parquet",img_dir="imgs/train_4layer/")
test_ds = HilbertImageDataset(annotations_file="target.parquet",img_dir="imgs/test_4layer/")

# %%
trainloader = DataLoader(train_ds, batch_size=64, shuffle=True)
testloader = DataLoader(test_ds, batch_size=64, shuffle=True)

# %%
a,b = next(iter(testloader))
a.shape,b
# Out:
# (torch.Size([64, 4, 32, 32]),
#  tensor([[-7.7918e-03,  1.7906e-03, -2.7127e-03,  1.7906e-03],
#          [-5.5943e-03,  1.2576e-04, -5.5943e-03,  1.2576e-04],
#          [-2.2596e-04,  1.7575e-03, -2.2596e-04,  1.4361e-03],
#          [-2.8445e-03,  7.9143e-04, -1.9553e-03,  7.9143e-04],
#          [-3.4988e-04,  1.4518e-02, -3.4988e-04,  1.0094e-02],
#          [-1.3639e-03,  8.5333e-03, -1.6199e-04,  8.5333e-03],
#          [-9.0052e-05,  4.2325e-03, -9.0052e-05,  4.2325e-03],
#          [-5.5402e-04,  2.5428e-03, -5.5402e-04,  2.5428e-03],
#          [-1.1265e-03,  5.5886e-03, -1.1265e-03,  5.5886e-03],
#          [-6.0381e-04,  3.2513e-03, -6.0381e-04,  1.7836e-03],
#          [-3.8686e-03,  1.6446e-03, -3.8686e-03,  8.3011e-04],
#          [-1.2929e-03,  2.1202e-03, -1.2929e-03,  2.0310e-03],
#          [-1.1643e-03,  2.0147e-03, -1.1643e-03,  5.0620e-06],
#          [-2.7706e-03,  2.9877e-03, -2.7706e-03,  5.0031e-04],
#          [-1.2473e-03,  2.8916e-04, -1.2473e-03,  2.8916e-04],
#          [-5.4897e-03,  7.4250e-04, -1.0712e-03,  7.4250e-04],
#          [-6.8457e-04,  2.3501e-03, -6.8457e-04,  2.3501e-03],
#          [-1.7233e-03,  3.1586e-03, -1.7233e-03,  9.4000e-04],
#          [-3.4651e-03,  6.6797e-04, -3.3273e-03,  6.6797e-04],
#          [-3.6002e-04,  7.1162e-03, -3.6002e-04,  5.2927e-03],
#          [-3.6057e-03,  1.1131e-03, -3.4803e-03,  8.2043e-04],
#          [-2.3658e-03,  1.1697e-03, -2.3658e-03,  7.7273e-04],
#          [-7.5509e-03,  1.5448e-03, -1.8673e-03,  1.5448e-03],
#          [-1.6189e-03,  1.5430e-03, -1.5531e-03,  5.8684e-04],
#          [-5.3416e-03,  4.4039e-03, -4.2468e-03,  2.0277e-03],
#          [-1.6657e-02,  4.7295e-04, -1.5651e-02,  4.7295e-04]],
#         dtype=torch.float64))

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 8, 3)
        self.pool = nn.MaxPool2d(3, 2)
        self.apool = nn.AdaptiveMaxPool2d(4)
        self.conv2 = nn.Conv2d(8, 16, 3)
        self.conv3 = nn.Conv2d(16, 32, 3)
        self.fc1 = nn.Linear(512, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 16)
        self.fc5 = nn.Linear(16, 4)
        
        self.batch1=nn.BatchNorm2d(8)
        self.batch2=nn.BatchNorm2d(16)
        self.batch3=nn.BatchNorm2d(32)
        self.dropout1=nn.Dropout2d(p=0.2)
        

    def forward(self, x):
        x = self.pool(self.batch1(F.relu(self.conv1(self.dropout1(x)))))
        x = self.pool(self.batch2(F.relu(self.conv2(self.dropout1(x)))))
        x = self.apool(self.batch3(F.relu(self.conv3(self.dropout1(x)))))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x


net = Net().to(device)

# %%
import torch.optim as optim

criterion = torch.nn.HuberLoss()
optimizer = optim.Adam(net.parameters(), lr=0.00125)

# %%
for epoch in range(4):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs = inputs.float().to(device)
        labels = labels.float().to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 200 == 199:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 200:.8f}')
            running_loss = 0.0

print('Finished Training')
# Out:
# [1,   200] loss: 0.00046960
# [1,   400] loss: 0.00004139
# [1,   600] loss: 0.00003539
# [1,   800] loss: 0.00002929
# [1,  1000] loss: 0.00002396
# [1,  1200] loss: 0.00002292
# [1,  1400] loss: 0.00001778
# [1,  1600] loss: 0.00001606
# [1,  1800] loss: 0.00001566
# [1,  2000] loss: 0.00001468
# [1,  2200] loss: 0.00001765
# [2,   200] loss: 0.00001302
# [2,   400] loss: 0.00001410
# [2,   600] loss: 0.00001438
# [2,   800] loss: 0.00001073
# [2,  1000] loss: 0.00001208
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
#       1 for epoch in range(4):  # loop over the dataset multiple times
#       3     running_loss = 0.0
# ----> 4     for i, data in enumerate(trainloader, 0):
#       5         # get the inputs; data is a list of [inputs, labels]
#       6         inputs, labels = data
#       7         inputs = inputs.float().to(device)
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:721, in _SingleProcessDataLoaderIter._next_data(self)
#     719 def _next_data(self):
#     720     index = self._next_index()  # may raise StopIteration
# --> 721     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722     if self._pin_memory:
#     723         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# Input In [3], in HilbertImageDataset.__getitem__(self, idx)
#      21 img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, -1])
#      22 image = np.load(img_path)
# ---> 23 label = self.img_labels.iloc[idx, :-1].values.astype("float64")
#      24 if self.transform:
#      25     image = self.transform(image)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1566, in _iLocIndexer._getitem_tuple(self, tup)
#    1564 tup = self._validate_tuple_indexer(tup)
#    1565 with suppress(IndexingError):
# -> 1566     return self._getitem_lowerdim(tup)
#    1568 return self._getitem_tuple_same_dim(tup)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:968, in _LocationIndexer._getitem_lowerdim(self, tup)
#     964 for i, key in enumerate(tup):
#     965     if is_label_like(key):
#     966         # We don't need to check for tuples here because those are
#     967         #  caught by the _is_nested_tuple_indexer check above.
# --> 968         section = self._getitem_axis(key, axis=i)
#     970         # We should never have a scalar section here, because
#     971         #  _getitem_lowerdim is only called after a check for
#     972         #  is_scalar_access, which that would be.
#     973         if section.ndim == self.ndim:
#     974             # we're in the middle of slicing through a MultiIndex
#     975             # revise the key wrt to `section` by inserting an _NS
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1628, in _iLocIndexer._getitem_axis(self, key, axis)
#    1625 # validate the location
#    1626 self._validate_integer(key, axis)
# -> 1628 return self.obj._ixs(key, axis=axis)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3714, in DataFrame._ixs(self, i, axis)
#    3712 # irow
#    3713 if axis == 0:
# -> 3714     new_mgr = self._mgr.fast_xs(i)
#    3716     # if we are a copy, mark as such
#    3717     copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py:1085, in BlockManager.fast_xs(self, loc)
#    1082     ref = weakref.ref(self.blocks[0])
#    1083     return SingleBlockManager(block, self.axes[0], [ref])
# -> 1085 dtype = interleaved_dtype([blk.dtype for blk in self.blocks])
#    1087 n = len(self)
#    1089 # GH#46406
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/base.py:226, in interleaved_dtype(dtypes)
#     223 if not len(dtypes):
#     224     return None
# --> 226 return find_common_type(dtypes)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:1614, in find_common_type(types)
#    1610 first = types[0]
#    1612 # workaround for find_common_type([np.dtype('datetime64[ns]')] * 2)
#    1613 # => object
# -> 1614 if lib.dtypes_all_equal(list(types)):
#    1615     return first
#    1617 # get unique types (dict.fromkeys is used as order-preserving set())
#
# KeyboardInterrupt:

# %%
torch.set_printoptions(sci_mode=False,precision=10)

# %%
dataiter = iter(testloader)
pd.set_option('display.max_rows', 500)
cols = list(pd.concat([pd.read_parquet("imgs/train/target.parquet"),
pd.read_parquet("imgs/test/target.parquet")]).iloc[:,:-1].columns)
fcs = [[i+"_target",i+"_pred"] for i in cols]
fullcols = [item for sublist in fcs for item in sublist]

# %%
tl = []
for images, labels in dataiter:
    images = images.float().to(device)
    labels = labels.float().to(device)
    outputs = net(images)
    evaldf = pd.DataFrame(labels.cpu(),columns=[i+"_target" for i in cols]).join(pd.DataFrame(outputs.cpu().tolist(),columns=[i+"_pred" for i in cols]))
    tl.append(evaldf[fullcols])

# %%
tf = pd.concat(tl)

# %%
tf.describe()
# Out:
#        Low_30_target   Low_30_pred  High_30_target  High_30_pred  \
# count   15830.000000  15830.000000    15830.000000  15830.000000
# mean       -0.003449     -0.003347        0.003528      0.002104
# std         0.004014      0.001714        0.004122      0.001587
# min        -0.068894     -0.015687       -0.000036      0.000890
# 25%        -0.004422     -0.003624        0.001070      0.001126
# 50%        -0.002293     -0.003035        0.002341      0.001722
# 75%        -0.001030     -0.002329        0.004498      0.002380
# max         0.000038     -0.001892        0.060375      0.016258
#
#        Low_15_target   Low_15_pred  High_15_target  High_15_pred
# count   15830.000000  15830.000000    15830.000000  15830.000000
# mean       -0.002381     -0.002492        0.002435      0.002943
# std         0.002858      0.000873        0.002918      0.001439
# min        -0.066908     -0.013585       -0.000042      0.001717
# 25%        -0.003090     -0.002723        0.000721      0.002127
# 50%        -0.001594     -0.002255        0.001609      0.002644
# 75%        -0.000693     -0.001930        0.003125      0.003197
# max         0.000038     -0.001604        0.059302      0.014021

# %%
(1.0002)**200
# Out:
# 1.0408066115126269

# %%
tf[(tf.High_30_target>0.01)].describe()
# Out:
#        Low_30_target  Low_30_pred  High_30_target  High_30_pred  \
# count     954.000000   954.000000      954.000000    954.000000
# mean       -0.002236    -0.003283        0.015426      0.002044
# std         0.004840     0.001821        0.007070      0.001684
# min        -0.059140    -0.015687        0.010011      0.000961
# 25%        -0.002430    -0.003528        0.011236      0.001101
# 50%        -0.001061    -0.002867        0.012971      0.001569
# 75%        -0.000378    -0.002299        0.016685      0.002265
# max         0.000023    -0.001944        0.060375      0.014827
#
#        Low_15_target  Low_15_pred  High_15_target  High_15_pred
# count     954.000000   954.000000      954.000000    954.000000
# mean       -0.001696    -0.002449        0.009052      0.002892
# std         0.002894     0.000922        0.006550      0.001538
# min        -0.057036    -0.010806        0.000004      0.001738
# 25%        -0.002112    -0.002647        0.004633      0.002090
# 50%        -0.000948    -0.002148        0.008055      0.002448
# 75%        -0.000332    -0.001884        0.011587      0.003102
# max         0.000023    -0.001635        0.059302      0.013559

# %%
tf[:5]
# Out:
#    Low_30_target  Low_30_pred  High_30_target  High_30_pred  Low_15_target  \
# 0      -0.003728    -0.002354        0.006844      0.001613      -0.002517
# 1      -0.000881    -0.006256        0.004615      0.005916      -0.000881
# 2      -0.000875    -0.006543        0.004832      0.006231      -0.000875
# 3      -0.000056    -0.005263        0.002482      0.004820      -0.000056
# 4      -0.007955    -0.003974        0.000591      0.003400      -0.003287
#
#    Low_15_pred  High_15_target  High_15_pred
# 0    -0.001910        0.004735      0.000508
# 1    -0.004530        0.002975      0.004087
# 2    -0.004723        0.004827      0.004350
# 3    -0.003863        0.001651      0.003176
# 4    -0.002998        0.000591      0.001994

# %%
for i in range(30,1):
    print(i)

# %%
np.random.rand()
# Out:
# 0.7428178260044163

# %%
pl=[]
margin=3
for k in range(1,31):
    profit = 1
    for i,row in tf.iloc[-50*(k+1):-50*k].iterrows():
        rnd = np.random.rand()
        if abs(row.High_30_pred)>abs(row.Low_30_pred):
            if row.High_30_pred<=row.High_30_target:
                if rnd>0.3:
                    profit*=1+row.High_30_pred*margin
                else:
                    profit*=(1-0.0025*margin)
        else:
            if row.Low_30_pred>=row.Low_30_target:
                if rnd>0.3:
                    profit*=1+abs(row.Low_30_pred)*margin
                else:
                    profit*=(1-0.0025*margin)

        profit*=0.99985
    pl.append(profit)

# %%
pl
# Out:
# [1.0444222370797054,
#  1.0986065706833297,
#  1.07045315220197,
#  1.0346964143229835,
#  1.0938160804012305,
#  1.0957838657335208,
#  1.1189699869490608,
#  1.1082404333828486,
#  1.0345186852176986,
#  1.0912429627034814,
#  1.074724699866966,
#  1.078013585905612,
#  1.0988887894213069,
#  1.0710251495589687,
#  1.0582824560243975,
#  0.9978562449571166,
#  1.0056377473448157,
#  1.0324433231302603,
#  1.0760969176823074,
#  1.14895062902932,
#  1.0585314706484101,
#  1.1340564330939455,
#  1.049820875553142,
#  1.040720905082264,
#  1.0717298441965786,
#  1.0467190980574097,
#  1.089705894952182,
#  1.110627974093764,
#  1.1106290748670455,
#  1.0591021522302493]

# %%
np.array(pl).prod()
# Out:
# 8.256073083891083

# %%
1.2**30
# Out:
# 237.37631379976955

# %%
with torch.no_grad():
    loss_r=0
    for i, data in enumerate(testloader, 0):
        inputs, labels = data
        inputs = inputs.float().to(device)
        labels = labels.float().to(device)
        net.eval()
        y_pred = net(inputs)
        test_loss = criterion(y_pred, labels)
        loss_r+=test_loss
        print(test_loss)
    print("Test Loss:",loss_r/i)
# Out:
# tensor(    0.0000049525, device='cuda:0')
# tensor(    0.0000061309, device='cuda:0')
# tensor(    0.0000086100, device='cuda:0')
# tensor(    0.0000079513, device='cuda:0')
# tensor(    0.0000060777, device='cuda:0')
# tensor(    0.0000083536, device='cuda:0')
# tensor(    0.0000044610, device='cuda:0')
# tensor(    0.0000114594, device='cuda:0')
# tensor(    0.0000036367, device='cuda:0')
# tensor(    0.0000050019, device='cuda:0')
# tensor(    0.0000103606, device='cuda:0')
# tensor(    0.0000038428, device='cuda:0')
# tensor(    0.0000067478, device='cuda:0')
# tensor(    0.0000069683, device='cuda:0')
# tensor(    0.0000065424, device='cuda:0')
# tensor(    0.0000052060, device='cuda:0')
# tensor(    0.0000052066, device='cuda:0')
# tensor(    0.0000029256, device='cuda:0')
# tensor(    0.0000047058, device='cuda:0')
# tensor(    0.0000025561, device='cuda:0')
# tensor(    0.0000062839, device='cuda:0')
# tensor(    0.0000049391, device='cuda:0')
# tensor(    0.0000090032, device='cuda:0')
# tensor(    0.0000054174, device='cuda:0')
# tensor(    0.0000052494, device='cuda:0')
# tensor(    0.0000044795, device='cuda:0')
# tensor(    0.0000041963, device='cuda:0')
# tensor(    0.0000047845, device='cuda:0')
# tensor(    0.0000052898, device='cuda:0')
# tensor(    0.0000046021, device='cuda:0')
# tensor(    0.0000049572, device='cuda:0')
# tensor(    0.0000031689, device='cuda:0')
# tensor(    0.0000077315, device='cuda:0')
# tensor(    0.0000034028, device='cuda:0')
# tensor(    0.0000108797, device='cuda:0')
# tensor(    0.0000107683, device='cuda:0')
# tensor(    0.0000064136, device='cuda:0')
# tensor(    0.0000034238, device='cuda:0')
# tensor(    0.0000045341, device='cuda:0')
# tensor(    0.0000053503, device='cuda:0')
# tensor(    0.0000051524, device='cuda:0')
# tensor(    0.0000040713, device='cuda:0')
# tensor(    0.0000049106, device='cuda:0')
# tensor(    0.0000037175, device='cuda:0')
# tensor(    0.0000033477, device='cuda:0')
# tensor(    0.0000129509, device='cuda:0')
# tensor(    0.0000223089, device='cuda:0')
# 1      -0.000400   -0.001244       0.000409     0.000587      -0.000400
# 2      -0.001068   -0.000126       0.003755     0.000722      -0.006299
# 3      -0.000790   -0.000598       0.002954     0.000795      -0.000790
# 4      -0.000174   -0.001125       0.002147     0.000693      -0.000719
# ..           ...         ...            ...          ...            ...
# 59     -0.000132   -0.001491       0.001864     0.000640      -0.003465
# 60     -0.000091   -0.001132       0.001868     0.000705      -0.000091
# 61     -0.000899   -0.001092       0.000374     0.000728      -0.002323
# 62     -0.000315   -0.001244       0.001932     0.000587      -0.000315
# 63     -0.002007   -0.001365       0.002488     0.000447      -0.002007
#
#     Low_10_pred  High_10_target  High_10_pred  Low_15_target  Low_15_pred  \
# 0     -0.001798        0.000626      0.001350      -0.000731    -0.001241
# 1     -0.002514        0.001570      0.001583      -0.000400    -0.001136
# 2     -0.001741        0.003755      0.001330      -0.007050    -0.001419
# 3     -0.001046        0.003165      0.001194      -0.000790    -0.001396
# 4     -0.001674        0.002147      0.001770      -0.000719    -0.001201
# ..          ...             ...           ...            ...          ...
# 59    -0.002018        0.001864      0.001639      -0.003465    -0.001121
# 60    -0.001583        0.001868      0.001707      -0.000091    -0.001212
# 61    -0.001411        0.000374      0.001646      -0.002323    -0.001237
# 62    -0.002514        0.001932      0.001583      -0.000315    -0.001136
# 63    -0.003576        0.004227      0.001932      -0.002007    -0.001004
#
#     High_15_target  High_15_pred
# 0         0.001273      0.002304
# 1         0.002869      0.002649
# 2         0.003755      0.001949
# 3         0.003165      0.001850
# 4         0.002147      0.002321
# ..             ...           ...
# 59        0.001864      0.002562
# 60        0.003389      0.002284
# 61        0.000374      0.002202
# 62        0.002751      0.002649
# 63        0.004227      0.003112
#
# [64 rows x 12 columns]

# %%
pd.DataFrame(outputs.cpu().tolist(),columns=[i+"_pred" for i in cols])
# Out:
#     Low_5_pred  High_5_pred  Low_10_pred  High_10_pred  Low_15_pred  \
# 0    -0.001583     0.002177    -0.001095      0.002055    -0.002646
# 1    -0.001246     0.002862    -0.000966      0.003397    -0.004058
# 2    -0.003334     0.002330    -0.002712      0.000254    -0.000268
# 3    -0.000888     0.002353    -0.001118      0.003457    -0.004103
# 4    -0.000888     0.002353    -0.001118      0.003457    -0.004103
# ..         ...          ...          ...           ...          ...
# 59   -0.002151     0.001271    -0.002539      0.000824    -0.000974
# 60   -0.002374     0.001515    -0.002606      0.000792    -0.000907
# 61   -0.002473     0.002786    -0.001652      0.001645    -0.002019
# 62   -0.003514     0.002429    -0.002278     -0.000182     0.000067
# 63   -0.002228     0.001012    -0.002445      0.000318    -0.000482
#
#     High_15_pred
# 0       0.003942
# 1       0.001613
# 2       0.002461
# 3       0.000942
# 4       0.000942
# ..           ...
# 59      0.001724
# 60      0.001597
# 61      0.003043
# 62      0.004801
# 63      0.003069
#
# [64 rows x 6 columns]

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 4

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
dataiter = iter(testloader)
images, labels = next(dataiter)

# %%
labels
# Out:
# tensor([3, 8, 8, 0])

# %%
images.shape
# Out:
# torch.Size([4, 3, 32, 32])
