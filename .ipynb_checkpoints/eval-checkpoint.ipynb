# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

import numpy as np
from hilbert import decode, encode
from tqdm import tqdm
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
os.environ["COMET_API_KEY"] = "uM0HPEvEu6OyX3dTEuB4Fihgz"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(5, 8, 3)
        self.pool = nn.MaxPool2d(3, 2)
        self.apool = nn.AdaptiveMaxPool2d(4)
        self.conv2 = nn.Conv2d(8, 16, 3)
        self.conv3 = nn.Conv2d(16, 32, 3)
        self.fc1 = nn.Linear(512, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 16)
        self.fc5 = nn.Linear(16, 4)
        
        self.batch1=nn.BatchNorm2d(8)
        self.batch2=nn.BatchNorm2d(16)
        self.batch3=nn.BatchNorm2d(32)
        self.dropout1=nn.Dropout2d(p=0.2)
        

    def forward(self, x):
        x = self.pool(self.batch1(F.relu(self.conv1(self.dropout1(x)))))
        x = self.pool(self.batch2(F.relu(self.conv2(self.dropout1(x)))))
        x = self.apool(self.batch3(F.relu(self.conv3(self.dropout1(x)))))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x
# Out:
# <style>.container { width:100% !important; }</style>
# cuda:0

# %%
df = pd.read_parquet("data/F_BTCUSDT_1m.parquet")
tc = ["Open",
"High",
"Low",
"Close",
"Volume"]
for i in tc:
    df[i]=df[i].astype("float")

# %%
df
# Out:
#                    OpenTime      Open      High       Low     Close    Volume  \
# 0       2019-10-01 00:00:00   8209.67   8216.04   8209.22   8211.91     3.282
# 1       2019-10-01 00:01:00   8215.93   8216.90   8210.87   8215.00     2.821
# 2       2019-10-01 00:02:00   8215.00   8215.00   8213.00   8214.58     1.241
# 3       2019-10-01 00:03:00   8214.31   8215.00   8213.04   8214.72     0.548
# 4       2019-10-01 00:04:00   8214.72   8215.00   8214.72   8215.00     1.055
# ...                     ...       ...       ...       ...       ...       ...
# 1583995 2022-10-04 23:55:00  20357.50  20375.00  20355.20  20355.30   954.064
# 1583996 2022-10-04 23:56:00  20355.20  20370.70  20353.30  20353.30   371.426
# 1583997 2022-10-04 23:57:00  20353.40  20355.30  20323.50  20330.00  1098.885
# 1583998 2022-10-04 23:58:00  20329.90  20360.40  20329.90  20344.00   595.273
# 1583999 2022-10-04 23:59:00  20344.10  20344.10  20322.70  20322.70   337.727
#
#              CloseTime      QuoteAsset  NumberOfTrades  \
# 0        1569877259999     26949.57673              33
# 1        1569877319999     23173.71997              18
# 2        1569877379999     10192.89112              27
# 3        1569877439999      4501.69900              23
# 4        1569877499999      8666.78673              17
# ...                ...             ...             ...
# 1583995  1664916959999  19430279.00560            5093
# 1583996  1664917019999   7562153.35400            3115
# 1583997  1664917079999  22345525.97800            6736
# 1583998  1664917139999  12111296.57470            3793
# 1583999  1664917199999   6866758.18540            2858
#
#         TakerBuybaseassetvolume TakerBuyquoteassetvolume Ignore
# 0                         1.650              13550.96373      0
# 1                         2.711              22270.40007      0
# 2                         0.400               3285.73147      0
# 3                         0.361               2965.55218      0
# 4                         0.948               7787.78280      0
# ...                         ...                      ...    ...
# 1583995                 509.076           10367821.83960      0
# 1583996                 163.501            3328771.53970      0
# 1583997                 442.725            9001848.01150      0
# 1583998                 384.144            7815856.88280      0
# 1583999                 101.121            2056048.84150      0
#
# [1584000 rows x 12 columns]

# %%
from comet_ml.integration.pytorch import load_model
model = Net()

# Load the model state dict from a Comet Experiment
checkpoint = load_model("experiment://eacde5338c4f4b36b341317e5ddefe7d/4_layer_w_volume_classic_CNN_mae_c")
model.load_state_dict(checkpoint['model_state_dict'])
#optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
model.to(device)
# Out:
# Net(
#   (conv1): Conv2d(5, 8, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (apool): AdaptiveMaxPool2d(output_size=4)
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=512, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=16, bias=True)
#   (fc5): Linear(in_features=16, out_features=4, bias=True)
#   (batch1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout2d(p=0.2, inplace=False)
# )

# %%
import os
import pandas as pd
from torchvision.io import read_image
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
class HilbertImageDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_dir = img_dir
        self.img_labels = pd.read_parquet(os.path.join(self.img_dir, annotations_file))
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, -1])
        image = np.load(img_path)
        label = self.img_labels.iloc[idx, :-1].values.astype("float64")
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label
train_ds = HilbertImageDataset(annotations_file="target.parquet",img_dir="imgs/train_4layer_w_volume/")
test_ds = HilbertImageDataset(annotations_file="target.parquet",img_dir="imgs/test_4layer_w_volume/")
trainloader = DataLoader(train_ds, batch_size=64, shuffle=True)
testloader = DataLoader(test_ds, batch_size=64, shuffle=True)

# %%
dataiter = iter(testloader)
cols = list(pd.concat([pd.read_parquet("imgs/train_4layer_w_volume/target.parquet"),
pd.read_parquet("imgs/test_4layer_w_volume/target.parquet")]).iloc[:,:-1].columns)
fcs = [[i+"_target",i+"_pred"] for i in cols]
fullcols = [item for sublist in fcs for item in sublist]
tl = []
for images, labels in dataiter:
    images = images.float().to(device)
    labels = labels.float().to(device)
    outputs = model(images)
    evaldf = pd.DataFrame(labels.cpu(),columns=[i+"_target" for i in cols]).join(pd.DataFrame(outputs.cpu().tolist(),columns=[i+"_pred" for i in cols]))
    tl.append(evaldf[fullcols])
tf = pd.concat(tl)

# %%
tr = pd.read_parquet("imgs/test_4layer_w_volume/target.parquet")

# %%
tr
# Out:
#           Low_30   High_30    Low_15   High_15        label
# 142468 -0.014369  0.002655 -0.009454  0.002655  0142468.npy
# 142469 -0.009648  0.000642 -0.006714  0.000642  0142469.npy
# 142470 -0.006290  0.005730 -0.006285  0.001253  0142470.npy
# 142471 -0.001220  0.010861 -0.001220  0.004109  0142471.npy
# 142472 -0.000316  0.011776 -0.000316  0.011776  0142472.npy
# ...          ...       ...       ...       ...          ...
# 158293 -0.000580  0.011258 -0.000580  0.004813  0158293.npy
# 158294 -0.001145  0.012076 -0.001145  0.007139  0158294.npy
# 158295 -0.000286  0.009678 -0.000286  0.002980  0158295.npy
# 158296 -0.001141  0.008595 -0.001141  0.008595  0158296.npy
# 158297 -0.001910  0.000658 -0.001910  0.000658  0158297.npy
#
# [15830 rows x 5 columns]

# %%
ohlc_mean,ohlc_std,vol_mean,vol_std = 28001.938870730588, 17834.47169281324, 248.00923831004107, 426.5438396373735

# %%
df[142468:]
# Out:
#                    OpenTime      Open      High       Low     Close    Volume  \
# 142468  2020-01-07 22:28:00   8074.58   8096.21   8067.00   8088.33   313.034
# 142469  2020-01-07 22:29:00   8088.33   8095.65   8071.69   8093.95   321.356
# 142470  2020-01-07 22:30:00   8092.93   8094.31   8073.50   8089.32   277.144
# 142471  2020-01-07 22:31:00   8090.47   8095.00   8075.00   8087.36   251.691
# 142472  2020-01-07 22:32:00   8088.71   8090.98   8084.09   8087.28   153.312
# ...                     ...       ...       ...       ...       ...       ...
# 1583995 2022-10-04 23:55:00  20357.50  20375.00  20355.20  20355.30   954.064
# 1583996 2022-10-04 23:56:00  20355.20  20370.70  20353.30  20353.30   371.426
# 1583997 2022-10-04 23:57:00  20353.40  20355.30  20323.50  20330.00  1098.885
# 1583998 2022-10-04 23:58:00  20329.90  20360.40  20329.90  20344.00   595.273
# 1583999 2022-10-04 23:59:00  20344.10  20344.10  20322.70  20322.70   337.727
#
#              CloseTime      QuoteAsset  NumberOfTrades  \
# 142468   1578425339999   2530121.30305             587
# 142469   1578425399999   2598223.61311             778
# 142470   1578425459999   2240511.64474             613
# 142471   1578425519999   2034537.59551             593
# 142472   1578425579999   1239979.89450             215
# ...                ...             ...             ...
# 1583995  1664916959999  19430279.00560            5093
# 1583996  1664917019999   7562153.35400            3115
# 1583997  1664917079999  22345525.97800            6736
# 1583998  1664917139999  12111296.57470            3793
# 1583999  1664917199999   6866758.18540            2858
#
#         TakerBuybaseassetvolume TakerBuyquoteassetvolume Ignore
# 142468                  222.572            1798759.38758      0
# 142469                  165.988            1342263.34096      0
# 142470                  152.105            1229739.05879      0
# 142471                  124.017            1002571.54378      0
# 142472                   76.370             617694.58186      0
# ...                         ...                      ...    ...
# 1583995                 509.076           10367821.83960      0
# 1583996                 163.501            3328771.53970      0
# 1583997                 442.725            9001848.01150      0
# 1583998                 384.144            7815856.88280      0
# 1583999                 101.121            2056048.84150      0
#
# [1441532 rows x 12 columns]

# %%
data = np.array(range(32*32))
locs = decode(data, 2, 5)

position_history = []

open_position=False
profit_margin=1.0
current_position=None
for i in tqdm(range(1424680,len(df))):
    if not open_position:
        pos_dict = {}
        temp_f = df.iloc[i-32*32:i]
        lv = temp_f.Close.iloc[-1]
        o1 = np.zeros((5,32,32))
        vals = temp_f[["Open","High","Low","Close","Volume"]].values
        for j in range(len(data)):
            o1[:,locs[j][0],locs[j][1]] = vals[j]
        ohlc = o1[:4,:,:]
        vol = o1[-1:,:,:]
        ohlc = (ohlc-ohlc_mean)/ohlc_std
        vol = (vol-vol_mean)/vol_std
        on1 = torch.Tensor(np.concatenate((ohlc,vol),axis=0).reshape((1,*o1.shape)))
        output=model(on1.to(device)).tolist()[0]
    

        if abs(output[2])<abs(output[3]):
            open_position=True
            pos_dict["time"]=temp_f["OpenTime"].iloc[-1]
            pos_dict["entry_price"]=temp_f["Close"].iloc[-1]
            pos_dict["type"]="long"
            pos_dict["take_profit"]=lv*(1+output[3])
            pos_dict["stop_loss"]=lv*(1+(output[2]*1/5))
            pos_dict["take_profit_ratio"]=(1+output[3])
            pos_dict["stop_loss_ratio"]=(1+(output[2]*1/5))
            print("Opened Position",pos_dict)
        
        elif abs(output[2])>abs(output[3]):
            open_position=True
            pos_dict["time"]=temp_f["OpenTime"].iloc[i]
            pos_dict["entry_price"]=temp_f["Close"].iloc[i]
            pos_dict["type"]="short"
            pos_dict["take_profit"]=lv*(1+output[2])
            pos_dict["stop_loss"]=lv*(1+(output[3]*1/5))
            pos_dict["take_profit_ratio"]=(1-output[2])
            pos_dict["stop_loss_ratio"]=(1-(output[3]*1/5))
            print("Opened Position",pos_dict)

        current_position=pos_dict
        print(current_position)
    elif open_position:
        current = df.iloc[i]
        if current_position["type"]=="long":
            if current.Low<current_position["stop_loss"]:
                current_position["result"] = "loss"
                profit_margin*=current_position["stop_loss_ratio"]*0.99985
                position_history.append(current_position)
                print("Closed Position", current_position)
                open_position=False
                current_position=None
            elif current.High>current_position["take_profit"]:
                current_position["result"] = "profit"
                profit_margin*=current_position["take_profit_ratio"]*0.99985
                position_history.append(current_position)
                print("Closed Position", current_position)
                open_position=False
                current_position=None
        elif current_position["type"]=="short":
            if current.High>current_position["stop_loss"]:
                current_position["result"] = "loss"
                profit_margin*=current_position["stop_loss_ratio"]*0.99985
                position_history.append(current_position)
                print("Closed Position", current_position)
                open_position=False
                current_position=None
            elif current.Low<current_position["take_profit"]:
                current_position["result"] = "profit"
                profit_margin*=current_position["take_profit_ratio"]*0.99985
                position_history.append(current_position)
                print("Closed Position", current_position)
                open_position=False
                current_position=None
        else:
            print("Error")
            break
                
        

    if i==32*32+1440*30:
        break
# Out:
#   0%|                                    | 201/159320 [00:00<02:35, 1025.60it/s]
# Opened Position {'time': Timestamp('2022-06-16 08:39:00'), 'entry_price': 22114.0, 'type': 'long', 'take_profit': 22152.855278648436, 'stop_loss': 22109.77391703129, 'take_profit_ratio': 1.0017570443451405, 'stop_loss_ratio': 0.9998088955879212}
# {'time': Timestamp('2022-06-16 08:39:00'), 'entry_price': 22114.0, 'type': 'long', 'take_profit': 22152.855278648436, 'stop_loss': 22109.77391703129, 'take_profit_ratio': 1.0017570443451405, 'stop_loss_ratio': 0.9998088955879212}
# Closed Position {'time': Timestamp('2022-06-16 08:39:00'), 'entry_price': 22114.0, 'type': 'long', 'take_profit': 22152.855278648436, 'stop_loss': 22109.77391703129, 'take_profit_ratio': 1.0017570443451405, 'stop_loss_ratio': 0.9998088955879212, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:41:00'), 'entry_price': 22092.8, 'type': 'long', 'take_profit': 22132.08402376175, 'stop_loss': 22089.126100387573, 'take_profit_ratio': 1.0017781369388103, 'stop_loss_ratio': 0.9998337060213089}
# {'time': Timestamp('2022-06-16 08:41:00'), 'entry_price': 22092.8, 'type': 'long', 'take_profit': 22132.08402376175, 'stop_loss': 22089.126100387573, 'take_profit_ratio': 1.0017781369388103, 'stop_loss_ratio': 0.9998337060213089}
# Closed Position {'time': Timestamp('2022-06-16 08:41:00'), 'entry_price': 22092.8, 'type': 'long', 'take_profit': 22132.08402376175, 'stop_loss': 22089.126100387573, 'take_profit_ratio': 1.0017781369388103, 'stop_loss_ratio': 0.9998337060213089, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:43:00'), 'entry_price': 22065.2, 'type': 'long', 'take_profit': 22110.587645152213, 'stop_loss': 22060.0359455961, 'take_profit_ratio': 1.0020569786429405, 'stop_loss_ratio': 0.9997659638524056}
# {'time': Timestamp('2022-06-16 08:43:00'), 'entry_price': 22065.2, 'type': 'long', 'take_profit': 22110.587645152213, 'stop_loss': 22060.0359455961, 'take_profit_ratio': 1.0020569786429405, 'stop_loss_ratio': 0.9997659638524056}
# Closed Position {'time': Timestamp('2022-06-16 08:43:00'), 'entry_price': 22065.2, 'type': 'long', 'take_profit': 22110.587645152213, 'stop_loss': 22060.0359455961, 'take_profit_ratio': 1.0020569786429405, 'stop_loss_ratio': 0.9997659638524056, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:46:00'), 'entry_price': 22034.0, 'type': 'long', 'take_profit': 22079.214707382023, 'stop_loss': 22028.90848712921, 'take_profit_ratio': 1.002052042633295, 'stop_loss_ratio': 0.9997689247131347}
# {'time': Timestamp('2022-06-16 08:46:00'), 'entry_price': 22034.0, 'type': 'long', 'take_profit': 22079.214707382023, 'stop_loss': 22028.90848712921, 'take_profit_ratio': 1.002052042633295, 'stop_loss_ratio': 0.9997689247131347}
# Closed Position {'time': Timestamp('2022-06-16 08:46:00'), 'entry_price': 22034.0, 'type': 'long', 'take_profit': 22079.214707382023, 'stop_loss': 22028.90848712921, 'take_profit_ratio': 1.002052042633295, 'stop_loss_ratio': 0.9997689247131347, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:48:00'), 'entry_price': 21983.9, 'type': 'long', 'take_profit': 22027.07161031477, 'stop_loss': 21979.22767880991, 'take_profit_ratio': 1.001963783055544, 'stop_loss_ratio': 0.9997874662280083}
# {'time': Timestamp('2022-06-16 08:48:00'), 'entry_price': 21983.9, 'type': 'long', 'take_profit': 22027.07161031477, 'stop_loss': 21979.22767880991, 'take_profit_ratio': 1.001963783055544, 'stop_loss_ratio': 0.9997874662280083}
# Closed Position {'time': Timestamp('2022-06-16 08:48:00'), 'entry_price': 21983.9, 'type': 'long', 'take_profit': 22027.07161031477, 'stop_loss': 21979.22767880991, 'take_profit_ratio': 1.001963783055544, 'stop_loss_ratio': 0.9997874662280083, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:50:00'), 'entry_price': 21940.2, 'type': 'long', 'take_profit': 21976.509013840558, 'stop_loss': 21937.398727493586, 'take_profit_ratio': 1.0016549080610275, 'stop_loss_ratio': 0.9998723223805428}
# {'time': Timestamp('2022-06-16 08:50:00'), 'entry_price': 21940.2, 'type': 'long', 'take_profit': 21976.509013840558, 'stop_loss': 21937.398727493586, 'take_profit_ratio': 1.0016549080610275, 'stop_loss_ratio': 0.9998723223805428}
# Closed Position {'time': Timestamp('2022-06-16 08:50:00'), 'entry_price': 21940.2, 'type': 'long', 'take_profit': 21976.509013840558, 'stop_loss': 21937.398727493586, 'take_profit_ratio': 1.0016549080610275, 'stop_loss_ratio': 0.9998723223805428, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:52:00'), 'entry_price': 21916.6, 'type': 'long', 'take_profit': 21959.282737663387, 'stop_loss': 21912.23672330022, 'take_profit_ratio': 1.00194750726223, 'stop_loss_ratio': 0.9998009145259857}
# {'time': Timestamp('2022-06-16 08:52:00'), 'entry_price': 21916.6, 'type': 'long', 'take_profit': 21959.282737663387, 'stop_loss': 21912.23672330022, 'take_profit_ratio': 1.00194750726223, 'stop_loss_ratio': 0.9998009145259857}
# Closed Position {'time': Timestamp('2022-06-16 08:52:00'), 'entry_price': 21916.6, 'type': 'long', 'take_profit': 21959.282737663387, 'stop_loss': 21912.23672330022, 'take_profit_ratio': 1.00194750726223, 'stop_loss_ratio': 0.9998009145259857, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:55:00'), 'entry_price': 21943.7, 'type': 'long', 'take_profit': 21992.666326727347, 'stop_loss': 21937.68096126139, 'take_profit_ratio': 1.002231452614069, 'stop_loss_ratio': 0.9997257053852081}
# {'time': Timestamp('2022-06-16 08:55:00'), 'entry_price': 21943.7, 'type': 'long', 'take_profit': 21992.666326727347, 'stop_loss': 21937.68096126139, 'take_profit_ratio': 1.002231452614069, 'stop_loss_ratio': 0.9997257053852081}
# Closed Position {'time': Timestamp('2022-06-16 08:55:00'), 'entry_price': 21943.7, 'type': 'long', 'take_profit': 21992.666326727347, 'stop_loss': 21937.68096126139, 'take_profit_ratio': 1.002231452614069, 'stop_loss_ratio': 0.9997257053852081, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:57:00'), 'entry_price': 21940.1, 'type': 'long', 'take_profit': 21989.4843688868, 'stop_loss': 21934.66352977648, 'take_profit_ratio': 1.0022508725523949, 'stop_loss_ratio': 0.9997522130608558}
# {'time': Timestamp('2022-06-16 08:57:00'), 'entry_price': 21940.1, 'type': 'long', 'take_profit': 21989.4843688868, 'stop_loss': 21934.66352977648, 'take_profit_ratio': 1.0022508725523949, 'stop_loss_ratio': 0.9997522130608558}
# Closed Position {'time': Timestamp('2022-06-16 08:57:00'), 'entry_price': 21940.1, 'type': 'long', 'take_profit': 21989.4843688868, 'stop_loss': 21934.66352977648, 'take_profit_ratio': 1.0022508725523949, 'stop_loss_ratio': 0.9997522130608558, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 08:59:00'), 'entry_price': 21931.9, 'type': 'long', 'take_profit': 21979.320652283357, 'stop_loss': 21926.329281535298, 'take_profit_ratio': 1.0021621771156788, 'stop_loss_ratio': 0.999745999276638}
# {'time': Timestamp('2022-06-16 08:59:00'), 'entry_price': 21931.9, 'type': 'long', 'take_profit': 21979.320652283357, 'stop_loss': 21926.329281535298, 'take_profit_ratio': 1.0021621771156788, 'stop_loss_ratio': 0.999745999276638}
# Closed Position {'time': Timestamp('2022-06-16 08:59:00'), 'entry_price': 21931.9, 'type': 'long', 'take_profit': 21979.320652283357, 'stop_loss': 21926.329281535298, 'take_profit_ratio': 1.0021621771156788, 'stop_loss_ratio': 0.999745999276638, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:02:00'), 'entry_price': 21926.3, 'type': 'long', 'take_profit': 21976.469716763124, 'stop_loss': 21919.999161445943, 'take_profit_ratio': 1.002288106828928, 'stop_loss_ratio': 0.999712635576725}
# {'time': Timestamp('2022-06-16 09:02:00'), 'entry_price': 21926.3, 'type': 'long', 'take_profit': 21976.469716763124, 'stop_loss': 21919.999161445943, 'take_profit_ratio': 1.002288106828928, 'stop_loss_ratio': 0.999712635576725}
# Closed Position {'time': Timestamp('2022-06-16 09:02:00'), 'entry_price': 21926.3, 'type': 'long', 'take_profit': 21976.469716763124, 'stop_loss': 21919.999161445943, 'take_profit_ratio': 1.002288106828928, 'stop_loss_ratio': 0.999712635576725, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:10:00'), 'entry_price': 21920.2, 'type': 'long', 'take_profit': 21961.400041574987, 'stop_loss': 21915.967249111534, 'take_profit_ratio': 1.001879546791315, 'stop_loss_ratio': 0.9998069018125534}
# {'time': Timestamp('2022-06-16 09:10:00'), 'entry_price': 21920.2, 'type': 'long', 'take_profit': 21961.400041574987, 'stop_loss': 21915.967249111534, 'take_profit_ratio': 1.001879546791315, 'stop_loss_ratio': 0.9998069018125534}
# Closed Position {'time': Timestamp('2022-06-16 09:10:00'), 'entry_price': 21920.2, 'type': 'long', 'take_profit': 21961.400041574987, 'stop_loss': 21915.967249111534, 'take_profit_ratio': 1.001879546791315, 'stop_loss_ratio': 0.9998069018125534, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:12:00'), 'entry_price': 21946.1, 'type': 'long', 'take_profit': 21993.302899949995, 'stop_loss': 21941.615542189775, 'take_profit_ratio': 1.0021508559584618, 'stop_loss_ratio': 0.9997956603765488}
# {'time': Timestamp('2022-06-16 09:12:00'), 'entry_price': 21946.1, 'type': 'long', 'take_profit': 21993.302899949995, 'stop_loss': 21941.615542189775, 'take_profit_ratio': 1.0021508559584618, 'stop_loss_ratio': 0.9997956603765488}
# Closed Position {'time': Timestamp('2022-06-16 09:12:00'), 'entry_price': 21946.1, 'type': 'long', 'take_profit': 21993.302899949995, 'stop_loss': 21941.615542189775, 'take_profit_ratio': 1.0021508559584618, 'stop_loss_ratio': 0.9997956603765488, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 09:15:00'), 'entry_price': 21973.4, 'type': 'long', 'take_profit': 22021.159965522587, 'stop_loss': 21967.82047587991, 'take_profit_ratio': 1.0021735355257988, 'stop_loss_ratio': 0.9997460782527924}
# {'time': Timestamp('2022-06-16 09:15:00'), 'entry_price': 21973.4, 'type': 'long', 'take_profit': 22021.159965522587, 'stop_loss': 21967.82047587991, 'take_profit_ratio': 1.0021735355257988, 'stop_loss_ratio': 0.9997460782527924}
# Closed Position {'time': Timestamp('2022-06-16 09:15:00'), 'entry_price': 21973.4, 'type': 'long', 'take_profit': 22021.159965522587, 'stop_loss': 21967.82047587991, 'take_profit_ratio': 1.0021735355257988, 'stop_loss_ratio': 0.9997460782527924, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:17:00'), 'entry_price': 21944.4, 'type': 'long', 'take_profit': 21996.20793980062, 'stop_loss': 21937.725532583, 'take_profit_ratio': 1.0023608729243279, 'stop_loss_ratio': 0.9996958464384079}
# {'time': Timestamp('2022-06-16 09:17:00'), 'entry_price': 21944.4, 'type': 'long', 'take_profit': 21996.20793980062, 'stop_loss': 21937.725532583, 'take_profit_ratio': 1.0023608729243279, 'stop_loss_ratio': 0.9996958464384079}
# Closed Position {'time': Timestamp('2022-06-16 09:17:00'), 'entry_price': 21944.4, 'type': 'long', 'take_profit': 21996.20793980062, 'stop_loss': 21937.725532583, 'take_profit_ratio': 1.0023608729243279, 'stop_loss_ratio': 0.9996958464384079, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:20:00'), 'entry_price': 21957.9, 'type': 'long', 'take_profit': 22012.29686557576, 'stop_loss': 21950.705107738675, 'take_profit_ratio': 1.0024773254990578, 'stop_loss_ratio': 0.999672332406044}
# {'time': Timestamp('2022-06-16 09:20:00'), 'entry_price': 21957.9, 'type': 'long', 'take_profit': 22012.29686557576, 'stop_loss': 21950.705107738675, 'take_profit_ratio': 1.0024773254990578, 'stop_loss_ratio': 0.999672332406044}
# Closed Position {'time': Timestamp('2022-06-16 09:20:00'), 'entry_price': 21957.9, 'type': 'long', 'take_profit': 22012.29686557576, 'stop_loss': 21950.705107738675, 'take_profit_ratio': 1.0024773254990578, 'stop_loss_ratio': 0.999672332406044, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:22:00'), 'entry_price': 21900.2, 'type': 'long', 'take_profit': 21941.411401400717, 'stop_loss': 21895.969544650914, 'take_profit_ratio': 1.0018817819654942, 'stop_loss_ratio': 0.9998068302869797}
# {'time': Timestamp('2022-06-16 09:22:00'), 'entry_price': 21900.2, 'type': 'long', 'take_profit': 21941.411401400717, 'stop_loss': 21895.969544650914, 'take_profit_ratio': 1.0018817819654942, 'stop_loss_ratio': 0.9998068302869797}
# Closed Position {'time': Timestamp('2022-06-16 09:22:00'), 'entry_price': 21900.2, 'type': 'long', 'take_profit': 21941.411401400717, 'stop_loss': 21895.969544650914, 'take_profit_ratio': 1.0018817819654942, 'stop_loss_ratio': 0.9998068302869797, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:24:00'), 'entry_price': 21854.7, 'type': 'long', 'take_profit': 21894.908639198544, 'stop_loss': 21850.67926634431, 'take_profit_ratio': 1.001839816570282, 'stop_loss_ratio': 0.9998160243034363}
# {'time': Timestamp('2022-06-16 09:24:00'), 'entry_price': 21854.7, 'type': 'long', 'take_profit': 21894.908639198544, 'stop_loss': 21850.67926634431, 'take_profit_ratio': 1.001839816570282, 'stop_loss_ratio': 0.9998160243034363}
# Closed Position {'time': Timestamp('2022-06-16 09:24:00'), 'entry_price': 21854.7, 'type': 'long', 'take_profit': 21894.908639198544, 'stop_loss': 21850.67926634431, 'take_profit_ratio': 1.001839816570282, 'stop_loss_ratio': 0.9998160243034363, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 09:26:00'), 'entry_price': 21883.7, 'type': 'long', 'take_profit': 21924.721300361307, 'stop_loss': 21878.871156431138, 'take_profit_ratio': 1.0018745139241219, 'stop_loss_ratio': 0.9997793406248092}
# {'time': Timestamp('2022-06-16 09:26:00'), 'entry_price': 21883.7, 'type': 'long', 'take_profit': 21924.721300361307, 'stop_loss': 21878.871156431138, 'take_profit_ratio': 1.0018745139241219, 'stop_loss_ratio': 0.9997793406248092}
# Closed Position {'time': Timestamp('2022-06-16 09:26:00'), 'entry_price': 21883.7, 'type': 'long', 'take_profit': 21924.721300361307, 'stop_loss': 21878.871156431138, 'take_profit_ratio': 1.0018745139241219, 'stop_loss_ratio': 0.9997793406248092, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:28:00'), 'entry_price': 21880.0, 'type': 'long', 'take_profit': 21924.32600811124, 'stop_loss': 21875.036308705807, 'take_profit_ratio': 1.002025868743658, 'stop_loss_ratio': 0.9997731402516365}
# {'time': Timestamp('2022-06-16 09:28:00'), 'entry_price': 21880.0, 'type': 'long', 'take_profit': 21924.32600811124, 'stop_loss': 21875.036308705807, 'take_profit_ratio': 1.002025868743658, 'stop_loss_ratio': 0.9997731402516365}
# Closed Position {'time': Timestamp('2022-06-16 09:28:00'), 'entry_price': 21880.0, 'type': 'long', 'take_profit': 21924.32600811124, 'stop_loss': 21875.036308705807, 'take_profit_ratio': 1.002025868743658, 'stop_loss_ratio': 0.9997731402516365, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:30:00'), 'entry_price': 21864.0, 'type': 'long', 'take_profit': 21903.46574190259, 'stop_loss': 21860.21678956747, 'take_profit_ratio': 1.001805055886507, 'stop_loss_ratio': 0.9998269662261009}
# {'time': Timestamp('2022-06-16 09:30:00'), 'entry_price': 21864.0, 'type': 'long', 'take_profit': 21903.46574190259, 'stop_loss': 21860.21678956747, 'take_profit_ratio': 1.001805055886507, 'stop_loss_ratio': 0.9998269662261009}
# Closed Position {'time': Timestamp('2022-06-16 09:30:00'), 'entry_price': 21864.0, 'type': 'long', 'take_profit': 21903.46574190259, 'stop_loss': 21860.21678956747, 'take_profit_ratio': 1.001805055886507, 'stop_loss_ratio': 0.9998269662261009, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:32:00'), 'entry_price': 21828.4, 'type': 'long', 'take_profit': 21877.981735645237, 'stop_loss': 21822.11630034745, 'take_profit_ratio': 1.002271432429552, 'stop_loss_ratio': 0.9997121319174767}
# {'time': Timestamp('2022-06-16 09:32:00'), 'entry_price': 21828.4, 'type': 'long', 'take_profit': 21877.981735645237, 'stop_loss': 21822.11630034745, 'take_profit_ratio': 1.002271432429552, 'stop_loss_ratio': 0.9997121319174767}
# Closed Position {'time': Timestamp('2022-06-16 09:32:00'), 'entry_price': 21828.4, 'type': 'long', 'take_profit': 21877.981735645237, 'stop_loss': 21822.11630034745, 'take_profit_ratio': 1.002271432429552, 'stop_loss_ratio': 0.9997121319174767, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:34:00'), 'entry_price': 21809.2, 'type': 'long', 'take_profit': 21858.248619395494, 'stop_loss': 21803.129653662443, 'take_profit_ratio': 1.0022489875555038, 'stop_loss_ratio': 0.9997216612100601}
# {'time': Timestamp('2022-06-16 09:34:00'), 'entry_price': 21809.2, 'type': 'long', 'take_profit': 21858.248619395494, 'stop_loss': 21803.129653662443, 'take_profit_ratio': 1.0022489875555038, 'stop_loss_ratio': 0.9997216612100601}
# Closed Position {'time': Timestamp('2022-06-16 09:34:00'), 'entry_price': 21809.2, 'type': 'long', 'take_profit': 21858.248619395494, 'stop_loss': 21803.129653662443, 'take_profit_ratio': 1.0022489875555038, 'stop_loss_ratio': 0.9997216612100601, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:36:00'), 'entry_price': 21791.7, 'type': 'long', 'take_profit': 21837.610200015082, 'stop_loss': 21786.349529158026, 'take_profit_ratio': 1.00210677459836, 'stop_loss_ratio': 0.9997544720768928}
# {'time': Timestamp('2022-06-16 09:36:00'), 'entry_price': 21791.7, 'type': 'long', 'take_profit': 21837.610200015082, 'stop_loss': 21786.349529158026, 'take_profit_ratio': 1.00210677459836, 'stop_loss_ratio': 0.9997544720768928}
# Closed Position {'time': Timestamp('2022-06-16 09:36:00'), 'entry_price': 21791.7, 'type': 'long', 'take_profit': 21837.610200015082, 'stop_loss': 21786.349529158026, 'take_profit_ratio': 1.00210677459836, 'stop_loss_ratio': 0.9997544720768928, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:38:00'), 'entry_price': 21802.9, 'type': 'long', 'take_profit': 21850.5851074975, 'stop_loss': 21797.142747872622, 'take_profit_ratio': 1.0021870993077755, 'stop_loss_ratio': 0.9997359409928321}
# {'time': Timestamp('2022-06-16 09:38:00'), 'entry_price': 21802.9, 'type': 'long', 'take_profit': 21850.5851074975, 'stop_loss': 21797.142747872622, 'take_profit_ratio': 1.0021870993077755, 'stop_loss_ratio': 0.9997359409928321}
# Closed Position {'time': Timestamp('2022-06-16 09:38:00'), 'entry_price': 21802.9, 'type': 'long', 'take_profit': 21850.5851074975, 'stop_loss': 21797.142747872622, 'take_profit_ratio': 1.0021870993077755, 'stop_loss_ratio': 0.9997359409928321, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:40:00'), 'entry_price': 21768.0, 'type': 'long', 'take_profit': 21816.44637823105, 'stop_loss': 21762.058672356605, 'take_profit_ratio': 1.0022255778312683, 'stop_loss_ratio': 0.9997270613908767}
# {'time': Timestamp('2022-06-16 09:40:00'), 'entry_price': 21768.0, 'type': 'long', 'take_profit': 21816.44637823105, 'stop_loss': 21762.058672356605, 'take_profit_ratio': 1.0022255778312683, 'stop_loss_ratio': 0.9997270613908767}
# Closed Position {'time': Timestamp('2022-06-16 09:40:00'), 'entry_price': 21768.0, 'type': 'long', 'take_profit': 21816.44637823105, 'stop_loss': 21762.058672356605, 'take_profit_ratio': 1.0022255778312683, 'stop_loss_ratio': 0.9997270613908767, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:42:00'), 'entry_price': 21760.1, 'type': 'long', 'take_profit': 21806.544219403713, 'stop_loss': 21754.737443694026, 'take_profit_ratio': 1.0021343752741814, 'stop_loss_ratio': 0.9997535601258278}
# {'time': Timestamp('2022-06-16 09:42:00'), 'entry_price': 21760.1, 'type': 'long', 'take_profit': 21806.544219403713, 'stop_loss': 21754.737443694026, 'take_profit_ratio': 1.0021343752741814, 'stop_loss_ratio': 0.9997535601258278}
# Closed Position {'time': Timestamp('2022-06-16 09:42:00'), 'entry_price': 21760.1, 'type': 'long', 'take_profit': 21806.544219403713, 'stop_loss': 21754.737443694026, 'take_profit_ratio': 1.0021343752741814, 'stop_loss_ratio': 0.9997535601258278, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:44:00'), 'entry_price': 21752.5, 'type': 'long', 'take_profit': 21796.342839449644, 'stop_loss': 21747.621309112757, 'take_profit_ratio': 1.0020155310630798, 'stop_loss_ratio': 0.9997757181525231}
# {'time': Timestamp('2022-06-16 09:44:00'), 'entry_price': 21752.5, 'type': 'long', 'take_profit': 21796.342839449644, 'stop_loss': 21747.621309112757, 'take_profit_ratio': 1.0020155310630798, 'stop_loss_ratio': 0.9997757181525231}
# Closed Position {'time': Timestamp('2022-06-16 09:44:00'), 'entry_price': 21752.5, 'type': 'long', 'take_profit': 21796.342839449644, 'stop_loss': 21747.621309112757, 'take_profit_ratio': 1.0020155310630798, 'stop_loss_ratio': 0.9997757181525231, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:46:00'), 'entry_price': 21762.0, 'type': 'long', 'take_profit': 21810.21502815932, 'stop_loss': 21756.36565116048, 'take_profit_ratio': 1.0022155605256557, 'stop_loss_ratio': 0.9997410923242569}
# {'time': Timestamp('2022-06-16 09:46:00'), 'entry_price': 21762.0, 'type': 'long', 'take_profit': 21810.21502815932, 'stop_loss': 21756.36565116048, 'take_profit_ratio': 1.0022155605256557, 'stop_loss_ratio': 0.9997410923242569}
# Closed Position {'time': Timestamp('2022-06-16 09:46:00'), 'entry_price': 21762.0, 'type': 'long', 'take_profit': 21810.21502815932, 'stop_loss': 21756.36565116048, 'take_profit_ratio': 1.0022155605256557, 'stop_loss_ratio': 0.9997410923242569, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:48:00'), 'entry_price': 21736.9, 'type': 'long', 'take_profit': 21789.163780440766, 'stop_loss': 21730.070462004842, 'take_profit_ratio': 1.0024043805897236, 'stop_loss_ratio': 0.9996858090162277}
# {'time': Timestamp('2022-06-16 09:48:00'), 'entry_price': 21736.9, 'type': 'long', 'take_profit': 21789.163780440766, 'stop_loss': 21730.070462004842, 'take_profit_ratio': 1.0024043805897236, 'stop_loss_ratio': 0.9996858090162277}
# Closed Position {'time': Timestamp('2022-06-16 09:48:00'), 'entry_price': 21736.9, 'type': 'long', 'take_profit': 21789.163780440766, 'stop_loss': 21730.070462004842, 'take_profit_ratio': 1.0024043805897236, 'stop_loss_ratio': 0.9996858090162277, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 09:52:00'), 'entry_price': 21791.9, 'type': 'long', 'take_profit': 21839.213431705164, 'stop_loss': 21786.5512010929, 'take_profit_ratio': 1.0021711476147175, 'stop_loss_ratio': 0.9997545510530472}
# {'time': Timestamp('2022-06-16 09:52:00'), 'entry_price': 21791.9, 'type': 'long', 'take_profit': 21839.213431705164, 'stop_loss': 21786.5512010929, 'take_profit_ratio': 1.0021711476147175, 'stop_loss_ratio': 0.9997545510530472}
# Closed Position {'time': Timestamp('2022-06-16 09:52:00'), 'entry_price': 21791.9, 'type': 'long', 'take_profit': 21839.213431705164, 'stop_loss': 21786.5512010929, 'take_profit_ratio': 1.0021711476147175, 'stop_loss_ratio': 0.9997545510530472, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:54:00'), 'entry_price': 21767.1, 'type': 'long', 'take_profit': 21817.434392179548, 'stop_loss': 21761.06394683808, 'take_profit_ratio': 1.0023124068975449, 'stop_loss_ratio': 0.9997226983308792}
# {'time': Timestamp('2022-06-16 09:54:00'), 'entry_price': 21767.1, 'type': 'long', 'take_profit': 21817.434392179548, 'stop_loss': 21761.06394683808, 'take_profit_ratio': 1.0023124068975449, 'stop_loss_ratio': 0.9997226983308792}
# Closed Position {'time': Timestamp('2022-06-16 09:54:00'), 'entry_price': 21767.1, 'type': 'long', 'take_profit': 21817.434392179548, 'stop_loss': 21761.06394683808, 'take_profit_ratio': 1.0023124068975449, 'stop_loss_ratio': 0.9997226983308792, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:56:00'), 'entry_price': 21775.4, 'type': 'long', 'take_profit': 21832.08181300983, 'stop_loss': 21767.49459453285, 'take_profit_ratio': 1.0026030205190182, 'stop_loss_ratio': 0.9996369570493698}
# {'time': Timestamp('2022-06-16 09:56:00'), 'entry_price': 21775.4, 'type': 'long', 'take_profit': 21832.08181300983, 'stop_loss': 21767.49459453285, 'take_profit_ratio': 1.0026030205190182, 'stop_loss_ratio': 0.9996369570493698}
# Closed Position {'time': Timestamp('2022-06-16 09:56:00'), 'entry_price': 21775.4, 'type': 'long', 'take_profit': 21832.08181300983, 'stop_loss': 21767.49459453285, 'take_profit_ratio': 1.0026030205190182, 'stop_loss_ratio': 0.9996369570493698, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 09:58:00'), 'entry_price': 21719.7, 'type': 'long', 'take_profit': 21777.376553842798, 'stop_loss': 21711.757692020685, 'take_profit_ratio': 1.0026554949581623, 'stop_loss_ratio': 0.9996343269944191}
# {'time': Timestamp('2022-06-16 09:58:00'), 'entry_price': 21719.7, 'type': 'long', 'take_profit': 21777.376553842798, 'stop_loss': 21711.757692020685, 'take_profit_ratio': 1.0026554949581623, 'stop_loss_ratio': 0.9996343269944191}
# Closed Position {'time': Timestamp('2022-06-16 09:58:00'), 'entry_price': 21719.7, 'type': 'long', 'take_profit': 21777.376553842798, 'stop_loss': 21711.757692020685, 'take_profit_ratio': 1.0026554949581623, 'stop_loss_ratio': 0.9996343269944191, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 10:00:00'), 'entry_price': 21812.3, 'type': 'long', 'take_profit': 21870.758262320236, 'stop_loss': 21803.92177032426, 'take_profit_ratio': 1.0026800595223904, 'stop_loss_ratio': 0.9996158942580223}
# {'time': Timestamp('2022-06-16 10:00:00'), 'entry_price': 21812.3, 'type': 'long', 'take_profit': 21870.758262320236, 'stop_loss': 21803.92177032426, 'take_profit_ratio': 1.0026800595223904, 'stop_loss_ratio': 0.9996158942580223}
# Closed Position {'time': Timestamp('2022-06-16 10:00:00'), 'entry_price': 21812.3, 'type': 'long', 'take_profit': 21870.758262320236, 'stop_loss': 21803.92177032426, 'take_profit_ratio': 1.0026800595223904, 'stop_loss_ratio': 0.9996158942580223, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 10:02:00'), 'entry_price': 21848.5, 'type': 'long', 'take_profit': 21898.45198275335, 'stop_loss': 21842.432421361656, 'take_profit_ratio': 1.0022862888872623, 'stop_loss_ratio': 0.9997222885489464}
# {'time': Timestamp('2022-06-16 10:02:00'), 'entry_price': 21848.5, 'type': 'long', 'take_profit': 21898.45198275335, 'stop_loss': 21842.432421361656, 'take_profit_ratio': 1.0022862888872623, 'stop_loss_ratio': 0.9997222885489464}
# Closed Position {'time': Timestamp('2022-06-16 10:02:00'), 'entry_price': 21848.5, 'type': 'long', 'take_profit': 21898.45198275335, 'stop_loss': 21842.432421361656, 'take_profit_ratio': 1.0022862888872623, 'stop_loss_ratio': 0.9997222885489464, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:04:00'), 'entry_price': 21837.0, 'type': 'long', 'take_profit': 21888.501505091786, 'stop_loss': 21830.370368510485, 'take_profit_ratio': 1.0023584514856339, 'stop_loss_ratio': 0.9996964037418365}
# {'time': Timestamp('2022-06-16 10:04:00'), 'entry_price': 21837.0, 'type': 'long', 'take_profit': 21888.501505091786, 'stop_loss': 21830.370368510485, 'take_profit_ratio': 1.0023584514856339, 'stop_loss_ratio': 0.9996964037418365}
# Closed Position {'time': Timestamp('2022-06-16 10:04:00'), 'entry_price': 21837.0, 'type': 'long', 'take_profit': 21888.501505091786, 'stop_loss': 21830.370368510485, 'take_profit_ratio': 1.0023584514856339, 'stop_loss_ratio': 0.9996964037418365, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 10:09:00'), 'entry_price': 21879.3, 'type': 'long', 'take_profit': 21932.89533008225, 'stop_loss': 21872.197437120078, 'take_profit_ratio': 1.0024495907127857, 'stop_loss_ratio': 0.9996753752231597}
# {'time': Timestamp('2022-06-16 10:09:00'), 'entry_price': 21879.3, 'type': 'long', 'take_profit': 21932.89533008225, 'stop_loss': 21872.197437120078, 'take_profit_ratio': 1.0024495907127857, 'stop_loss_ratio': 0.9996753752231597}
# Closed Position {'time': Timestamp('2022-06-16 10:09:00'), 'entry_price': 21879.3, 'type': 'long', 'take_profit': 21932.89533008225, 'stop_loss': 21872.197437120078, 'take_profit_ratio': 1.0024495907127857, 'stop_loss_ratio': 0.9996753752231597, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:11:00'), 'entry_price': 21871.5, 'type': 'long', 'take_profit': 21921.918229613453, 'stop_loss': 21865.128673032672, 'take_profit_ratio': 1.0023052021861076, 'stop_loss_ratio': 0.9997086927294732}
# {'time': Timestamp('2022-06-16 10:11:00'), 'entry_price': 21871.5, 'type': 'long', 'take_profit': 21921.918229613453, 'stop_loss': 21865.128673032672, 'take_profit_ratio': 1.0023052021861076, 'stop_loss_ratio': 0.9997086927294732}
# Closed Position {'time': Timestamp('2022-06-16 10:11:00'), 'entry_price': 21871.5, 'type': 'long', 'take_profit': 21921.918229613453, 'stop_loss': 21865.128673032672, 'take_profit_ratio': 1.0023052021861076, 'stop_loss_ratio': 0.9997086927294732, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 10:13:00'), 'entry_price': 21906.3, 'type': 'long', 'take_profit': 21957.557153967395, 'stop_loss': 21899.912463954537, 'take_profit_ratio': 1.0023398362100124, 'stop_loss_ratio': 0.9997084155678749}
# {'time': Timestamp('2022-06-16 10:13:00'), 'entry_price': 21906.3, 'type': 'long', 'take_profit': 21957.557153967395, 'stop_loss': 21899.912463954537, 'take_profit_ratio': 1.0023398362100124, 'stop_loss_ratio': 0.9997084155678749}
# Closed Position {'time': Timestamp('2022-06-16 10:13:00'), 'entry_price': 21906.3, 'type': 'long', 'take_profit': 21957.557153967395, 'stop_loss': 21899.912463954537, 'take_profit_ratio': 1.0023398362100124, 'stop_loss_ratio': 0.9997084155678749, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:15:00'), 'entry_price': 21879.7, 'type': 'long', 'take_profit': 21925.729411493616, 'stop_loss': 21874.2764747034, 'take_profit_ratio': 1.0021037496626377, 'stop_loss_ratio': 0.9997521206736565}
# {'time': Timestamp('2022-06-16 10:15:00'), 'entry_price': 21879.7, 'type': 'long', 'take_profit': 21925.729411493616, 'stop_loss': 21874.2764747034, 'take_profit_ratio': 1.0021037496626377, 'stop_loss_ratio': 0.9997521206736565}
# Closed Position {'time': Timestamp('2022-06-16 10:15:00'), 'entry_price': 21879.7, 'type': 'long', 'take_profit': 21925.729411493616, 'stop_loss': 21874.2764747034, 'take_profit_ratio': 1.0021037496626377, 'stop_loss_ratio': 0.9997521206736565, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:17:00'), 'entry_price': 21837.0, 'type': 'long', 'take_profit': 21881.321546506137, 'stop_loss': 21832.026995430886, 'take_profit_ratio': 1.0020296536386013, 'stop_loss_ratio': 0.9997722670435906}
# {'time': Timestamp('2022-06-16 10:17:00'), 'entry_price': 21837.0, 'type': 'long', 'take_profit': 21881.321546506137, 'stop_loss': 21832.026995430886, 'take_profit_ratio': 1.0020296536386013, 'stop_loss_ratio': 0.9997722670435906}
# Closed Position {'time': Timestamp('2022-06-16 10:17:00'), 'entry_price': 21837.0, 'type': 'long', 'take_profit': 21881.321546506137, 'stop_loss': 21832.026995430886, 'take_profit_ratio': 1.0020296536386013, 'stop_loss_ratio': 0.9997722670435906, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:19:00'), 'entry_price': 21840.0, 'type': 'long', 'take_profit': 21891.638431549072, 'stop_loss': 21833.959287643433, 'take_profit_ratio': 1.0023643970489502, 'stop_loss_ratio': 0.9997234106063843}
# {'time': Timestamp('2022-06-16 10:19:00'), 'entry_price': 21840.0, 'type': 'long', 'take_profit': 21891.638431549072, 'stop_loss': 21833.959287643433, 'take_profit_ratio': 1.0023643970489502, 'stop_loss_ratio': 0.9997234106063843}
# Closed Position {'time': Timestamp('2022-06-16 10:19:00'), 'entry_price': 21840.0, 'type': 'long', 'take_profit': 21891.638431549072, 'stop_loss': 21833.959287643433, 'take_profit_ratio': 1.0023643970489502, 'stop_loss_ratio': 0.9997234106063843, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:21:00'), 'entry_price': 21801.4, 'type': 'long', 'take_profit': 21845.08134354502, 'stop_loss': 21796.580350391272, 'take_profit_ratio': 1.0020036026835442, 'stop_loss_ratio': 0.9997789293527604}
# {'time': Timestamp('2022-06-16 10:21:00'), 'entry_price': 21801.4, 'type': 'long', 'take_profit': 21845.08134354502, 'stop_loss': 21796.580350391272, 'take_profit_ratio': 1.0020036026835442, 'stop_loss_ratio': 0.9997789293527604}
# Closed Position {'time': Timestamp('2022-06-16 10:21:00'), 'entry_price': 21801.4, 'type': 'long', 'take_profit': 21845.08134354502, 'stop_loss': 21796.580350391272, 'take_profit_ratio': 1.0020036026835442, 'stop_loss_ratio': 0.9997789293527604, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:23:00'), 'entry_price': 21781.9, 'type': 'long', 'take_profit': 21833.193493982406, 'stop_loss': 21775.362722779813, 'take_profit_ratio': 1.0023548677563667, 'stop_loss_ratio': 0.9996998757123947}
# {'time': Timestamp('2022-06-16 10:23:00'), 'entry_price': 21781.9, 'type': 'long', 'take_profit': 21833.193493982406, 'stop_loss': 21775.362722779813, 'take_profit_ratio': 1.0023548677563667, 'stop_loss_ratio': 0.9996998757123947}
# Closed Position {'time': Timestamp('2022-06-16 10:23:00'), 'entry_price': 21781.9, 'type': 'long', 'take_profit': 21833.193493982406, 'stop_loss': 21775.362722779813, 'take_profit_ratio': 1.0023548677563667, 'stop_loss_ratio': 0.9996998757123947, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:25:00'), 'entry_price': 21755.8, 'type': 'long', 'take_profit': 21808.31102944389, 'stop_loss': 21749.40337530762, 'take_profit_ratio': 1.0024136565625668, 'stop_loss_ratio': 0.9997059807181359}
# {'time': Timestamp('2022-06-16 10:25:00'), 'entry_price': 21755.8, 'type': 'long', 'take_profit': 21808.31102944389, 'stop_loss': 21749.40337530762, 'take_profit_ratio': 1.0024136565625668, 'stop_loss_ratio': 0.9997059807181359}
# Closed Position {'time': Timestamp('2022-06-16 10:25:00'), 'entry_price': 21755.8, 'type': 'long', 'take_profit': 21808.31102944389, 'stop_loss': 21749.40337530762, 'take_profit_ratio': 1.0024136565625668, 'stop_loss_ratio': 0.9997059807181359, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:27:00'), 'entry_price': 21814.5, 'type': 'long', 'take_profit': 21870.294266799465, 'stop_loss': 21806.850883128496, 'take_profit_ratio': 1.0025576688349247, 'stop_loss_ratio': 0.9996493563055993}
# {'time': Timestamp('2022-06-16 10:27:00'), 'entry_price': 21814.5, 'type': 'long', 'take_profit': 21870.294266799465, 'stop_loss': 21806.850883128496, 'take_profit_ratio': 1.0025576688349247, 'stop_loss_ratio': 0.9996493563055993}
# Closed Position {'time': Timestamp('2022-06-16 10:27:00'), 'entry_price': 21814.5, 'type': 'long', 'take_profit': 21870.294266799465, 'stop_loss': 21806.850883128496, 'take_profit_ratio': 1.0025576688349247, 'stop_loss_ratio': 0.9996493563055993, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:30:00'), 'entry_price': 21773.9, 'type': 'long', 'take_profit': 21816.782022618132, 'stop_loss': 21769.080978966653, 'take_profit_ratio': 1.0019694231450558, 'stop_loss_ratio': 0.9997786790132522}
# {'time': Timestamp('2022-06-16 10:30:00'), 'entry_price': 21773.9, 'type': 'long', 'take_profit': 21816.782022618132, 'stop_loss': 21769.080978966653, 'take_profit_ratio': 1.0019694231450558, 'stop_loss_ratio': 0.9997786790132522}
# Closed Position {'time': Timestamp('2022-06-16 10:30:00'), 'entry_price': 21773.9, 'type': 'long', 'take_profit': 21816.782022618132, 'stop_loss': 21769.080978966653, 'take_profit_ratio': 1.0019694231450558, 'stop_loss_ratio': 0.9997786790132522, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:32:00'), 'entry_price': 21759.6, 'type': 'long', 'take_profit': 21812.105124025045, 'stop_loss': 21752.740730111, 'take_profit_ratio': 1.0024129636585712, 'stop_loss_ratio': 0.9996847704052925}
# {'time': Timestamp('2022-06-16 10:32:00'), 'entry_price': 21759.6, 'type': 'long', 'take_profit': 21812.105124025045, 'stop_loss': 21752.740730111, 'take_profit_ratio': 1.0024129636585712, 'stop_loss_ratio': 0.9996847704052925}
# Closed Position {'time': Timestamp('2022-06-16 10:32:00'), 'entry_price': 21759.6, 'type': 'long', 'take_profit': 21812.105124025045, 'stop_loss': 21752.740730111, 'take_profit_ratio': 1.0024129636585712, 'stop_loss_ratio': 0.9996847704052925, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:34:00'), 'entry_price': 21711.0, 'type': 'long', 'take_profit': 21758.50789172575, 'stop_loss': 21705.261547422408, 'take_profit_ratio': 1.0021881945431232, 'stop_loss_ratio': 0.999735689163208}
# {'time': Timestamp('2022-06-16 10:34:00'), 'entry_price': 21711.0, 'type': 'long', 'take_profit': 21758.50789172575, 'stop_loss': 21705.261547422408, 'take_profit_ratio': 1.0021881945431232, 'stop_loss_ratio': 0.999735689163208}
# Closed Position {'time': Timestamp('2022-06-16 10:34:00'), 'entry_price': 21711.0, 'type': 'long', 'take_profit': 21758.50789172575, 'stop_loss': 21705.261547422408, 'take_profit_ratio': 1.0021881945431232, 'stop_loss_ratio': 0.999735689163208, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:36:00'), 'entry_price': 21660.9, 'type': 'long', 'take_profit': 21707.101664596797, 'stop_loss': 21655.45082449079, 'take_profit_ratio': 1.0021329522132874, 'stop_loss_ratio': 0.999748432636261}
# {'time': Timestamp('2022-06-16 10:36:00'), 'entry_price': 21660.9, 'type': 'long', 'take_profit': 21707.101664596797, 'stop_loss': 21655.45082449079, 'take_profit_ratio': 1.0021329522132874, 'stop_loss_ratio': 0.999748432636261}
# Closed Position {'time': Timestamp('2022-06-16 10:36:00'), 'entry_price': 21660.9, 'type': 'long', 'take_profit': 21707.101664596797, 'stop_loss': 21655.45082449079, 'take_profit_ratio': 1.0021329522132874, 'stop_loss_ratio': 0.999748432636261, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:38:00'), 'entry_price': 21688.1, 'type': 'long', 'take_profit': 21731.428942345825, 'stop_loss': 21683.08224337354, 'take_profit_ratio': 1.001997821033001, 'stop_loss_ratio': 0.999768640100956}
# {'time': Timestamp('2022-06-16 10:38:00'), 'entry_price': 21688.1, 'type': 'long', 'take_profit': 21731.428942345825, 'stop_loss': 21683.08224337354, 'take_profit_ratio': 1.001997821033001, 'stop_loss_ratio': 0.999768640100956}
# Closed Position {'time': Timestamp('2022-06-16 10:38:00'), 'entry_price': 21688.1, 'type': 'long', 'take_profit': 21731.428942345825, 'stop_loss': 21683.08224337354, 'take_profit_ratio': 1.001997821033001, 'stop_loss_ratio': 0.999768640100956, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:40:00'), 'entry_price': 21645.8, 'type': 'long', 'take_profit': 21692.56149305552, 'stop_loss': 21640.218088777958, 'take_profit_ratio': 1.0021603032946587, 'stop_loss_ratio': 0.9997421249747276}
# {'time': Timestamp('2022-06-16 10:40:00'), 'entry_price': 21645.8, 'type': 'long', 'take_profit': 21692.56149305552, 'stop_loss': 21640.218088777958, 'take_profit_ratio': 1.0021603032946587, 'stop_loss_ratio': 0.9997421249747276}
# Closed Position {'time': Timestamp('2022-06-16 10:40:00'), 'entry_price': 21645.8, 'type': 'long', 'take_profit': 21692.56149305552, 'stop_loss': 21640.218088777958, 'take_profit_ratio': 1.0021603032946587, 'stop_loss_ratio': 0.9997421249747276, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:42:00'), 'entry_price': 21662.0, 'type': 'long', 'take_profit': 21706.02671865374, 'stop_loss': 21657.05293649435, 'take_profit_ratio': 1.0020324401557446, 'stop_loss_ratio': 0.9997716248035431}
# {'time': Timestamp('2022-06-16 10:42:00'), 'entry_price': 21662.0, 'type': 'long', 'take_profit': 21706.02671865374, 'stop_loss': 21657.05293649435, 'take_profit_ratio': 1.0020324401557446, 'stop_loss_ratio': 0.9997716248035431}
# Closed Position {'time': Timestamp('2022-06-16 10:42:00'), 'entry_price': 21662.0, 'type': 'long', 'take_profit': 21706.02671865374, 'stop_loss': 21657.05293649435, 'take_profit_ratio': 1.0020324401557446, 'stop_loss_ratio': 0.9997716248035431, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 10:45:00'), 'entry_price': 21730.7, 'type': 'long', 'take_profit': 21780.03771648258, 'stop_loss': 21724.54406221569, 'take_profit_ratio': 1.0022704154253006, 'stop_loss_ratio': 0.999716717004776}
# {'time': Timestamp('2022-06-16 10:45:00'), 'entry_price': 21730.7, 'type': 'long', 'take_profit': 21780.03771648258, 'stop_loss': 21724.54406221569, 'take_profit_ratio': 1.0022704154253006, 'stop_loss_ratio': 0.999716717004776}
# Closed Position {'time': Timestamp('2022-06-16 10:45:00'), 'entry_price': 21730.7, 'type': 'long', 'take_profit': 21780.03771648258, 'stop_loss': 21724.54406221569, 'take_profit_ratio': 1.0022704154253006, 'stop_loss_ratio': 0.999716717004776, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:47:00'), 'entry_price': 21679.5, 'type': 'long', 'take_profit': 21720.600243436173, 'stop_loss': 21675.23231931478, 'take_profit_ratio': 1.0018958114087582, 'stop_loss_ratio': 0.9998031467199325}
# {'time': Timestamp('2022-06-16 10:47:00'), 'entry_price': 21679.5, 'type': 'long', 'take_profit': 21720.600243436173, 'stop_loss': 21675.23231931478, 'take_profit_ratio': 1.0018958114087582, 'stop_loss_ratio': 0.9998031467199325}
# Closed Position {'time': Timestamp('2022-06-16 10:47:00'), 'entry_price': 21679.5, 'type': 'long', 'take_profit': 21720.600243436173, 'stop_loss': 21675.23231931478, 'take_profit_ratio': 1.0018958114087582, 'stop_loss_ratio': 0.9998031467199325, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:50:00'), 'entry_price': 21679.9, 'type': 'long', 'take_profit': 21729.574576573446, 'stop_loss': 21673.924826669398, 'take_profit_ratio': 1.0022912733256817, 'stop_loss_ratio': 0.9997243911027909}
# {'time': Timestamp('2022-06-16 10:50:00'), 'entry_price': 21679.9, 'type': 'long', 'take_profit': 21729.574576573446, 'stop_loss': 21673.924826669398, 'take_profit_ratio': 1.0022912733256817, 'stop_loss_ratio': 0.9997243911027909}
# Closed Position {'time': Timestamp('2022-06-16 10:50:00'), 'entry_price': 21679.9, 'type': 'long', 'take_profit': 21729.574576573446, 'stop_loss': 21673.924826669398, 'take_profit_ratio': 1.0022912733256817, 'stop_loss_ratio': 0.9997243911027909, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 10:52:00'), 'entry_price': 21711.4, 'type': 'long', 'take_profit': 21757.153562611344, 'stop_loss': 21705.971572831273, 'take_profit_ratio': 1.0021073520183563, 'stop_loss_ratio': 0.9997499734163284}
# {'time': Timestamp('2022-06-16 10:52:00'), 'entry_price': 21711.4, 'type': 'long', 'take_profit': 21757.153562611344, 'stop_loss': 21705.971572831273, 'take_profit_ratio': 1.0021073520183563, 'stop_loss_ratio': 0.9997499734163284}
# Closed Position {'time': Timestamp('2022-06-16 10:52:00'), 'entry_price': 21711.4, 'type': 'long', 'take_profit': 21757.153562611344, 'stop_loss': 21705.971572831273, 'take_profit_ratio': 1.0021073520183563, 'stop_loss_ratio': 0.9997499734163284, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 10:55:00'), 'entry_price': 21735.6, 'type': 'long', 'take_profit': 21782.703665989637, 'stop_loss': 21730.43169143915, 'take_profit_ratio': 1.0021671205759048, 'stop_loss_ratio': 0.9997622191905975}
# {'time': Timestamp('2022-06-16 10:55:00'), 'entry_price': 21735.6, 'type': 'long', 'take_profit': 21782.703665989637, 'stop_loss': 21730.43169143915, 'take_profit_ratio': 1.0021671205759048, 'stop_loss_ratio': 0.9997622191905975}
# Closed Position {'time': Timestamp('2022-06-16 10:55:00'), 'entry_price': 21735.6, 'type': 'long', 'take_profit': 21782.703665989637, 'stop_loss': 21730.43169143915, 'take_profit_ratio': 1.0021671205759048, 'stop_loss_ratio': 0.9997622191905975, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-16 11:02:00'), 'entry_price': 21791.9, 'type': 'long', 'take_profit': 21839.844452812526, 'stop_loss': 21786.080220511853, 'take_profit_ratio': 1.0022001042962074, 'stop_loss_ratio': 0.9997329384088516}
# {'time': Timestamp('2022-06-16 11:02:00'), 'entry_price': 21791.9, 'type': 'long', 'take_profit': 21839.844452812526, 'stop_loss': 21786.080220511853, 'take_profit_ratio': 1.0022001042962074, 'stop_loss_ratio': 0.9997329384088516}
# Closed Position {'time': Timestamp('2022-06-16 11:02:00'), 'entry_price': 21791.9, 'type': 'long', 'take_profit': 21839.844452812526, 'stop_loss': 21786.080220511853, 'take_profit_ratio': 1.0022001042962074, 'stop_loss_ratio': 0.9997329384088516, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 11:04:00'), 'entry_price': 21766.4, 'type': 'long', 'take_profit': 21816.81621115208, 'stop_loss': 21760.31289449692, 'take_profit_ratio': 1.002316240221262, 'stop_loss_ratio': 0.9997203439474106}
# {'time': Timestamp('2022-06-16 11:04:00'), 'entry_price': 21766.4, 'type': 'long', 'take_profit': 21816.81621115208, 'stop_loss': 21760.31289449692, 'take_profit_ratio': 1.002316240221262, 'stop_loss_ratio': 0.9997203439474106}
# Closed Position {'time': Timestamp('2022-06-16 11:04:00'), 'entry_price': 21766.4, 'type': 'long', 'take_profit': 21816.81621115208, 'stop_loss': 21760.31289449692, 'take_profit_ratio': 1.002316240221262, 'stop_loss_ratio': 0.9997203439474106, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 11:06:00'), 'entry_price': 21712.8, 'type': 'long', 'take_profit': 21763.130239096285, 'stop_loss': 21706.73108716607, 'take_profit_ratio': 1.0023179985582829, 'stop_loss_ratio': 0.9997204914689064}
# {'time': Timestamp('2022-06-16 11:06:00'), 'entry_price': 21712.8, 'type': 'long', 'take_profit': 21763.130239096285, 'stop_loss': 21706.73108716607, 'take_profit_ratio': 1.0023179985582829, 'stop_loss_ratio': 0.9997204914689064}
# Closed Position {'time': Timestamp('2022-06-16 11:06:00'), 'entry_price': 21712.8, 'type': 'long', 'take_profit': 21763.130239096285, 'stop_loss': 21706.73108716607, 'take_profit_ratio': 1.0023179985582829, 'stop_loss_ratio': 0.9997204914689064, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 11:08:00'), 'entry_price': 21704.3, 'type': 'long', 'take_profit': 21758.111873156948, 'stop_loss': 21697.10540890664, 'take_profit_ratio': 1.0024793185293674, 'stop_loss_ratio': 0.9996685177087784}
# {'time': Timestamp('2022-06-16 11:08:00'), 'entry_price': 21704.3, 'type': 'long', 'take_profit': 21758.111873156948, 'stop_loss': 21697.10540890664, 'take_profit_ratio': 1.0024793185293674, 'stop_loss_ratio': 0.9996685177087784}
# Closed Position {'time': Timestamp('2022-06-16 11:08:00'), 'entry_price': 21704.3, 'type': 'long', 'take_profit': 21758.111873156948, 'stop_loss': 21697.10540890664, 'take_profit_ratio': 1.0024793185293674, 'stop_loss_ratio': 0.9996685177087784, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 11:10:00'), 'entry_price': 21681.1, 'type': 'long', 'take_profit': 21732.82125101648, 'stop_loss': 21674.382202113567, 'take_profit_ratio': 1.0023855455219746, 'stop_loss_ratio': 0.9996901541948319}
# {'time': Timestamp('2022-06-16 11:10:00'), 'entry_price': 21681.1, 'type': 'long', 'take_profit': 21732.82125101648, 'stop_loss': 21674.382202113567, 'take_profit_ratio': 1.0023855455219746, 'stop_loss_ratio': 0.9996901541948319}
# Closed Position {'time': Timestamp('2022-06-16 11:10:00'), 'entry_price': 21681.1, 'type': 'long', 'take_profit': 21732.82125101648, 'stop_loss': 21674.382202113567, 'take_profit_ratio': 1.0023855455219746, 'stop_loss_ratio': 0.9996901541948319, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-16 11:12:00'), 'entry_price': 21632.5, 'type': 'long', 'take_profit': 21676.529700383544, 'stop_loss': 21627.589716523886, 'take_profit_ratio': 1.0020353496074677, 'stop_loss_ratio': 0.9997730135917664}
# {'time': Timestamp('2022-06-16 11:12:00'), 'entry_price': 21632.5, 'type': 'long', 'take_profit': 21676.529700383544, 'stop_loss': 21627.589716523886, 'take_profit_ratio': 1.0020353496074677, 'stop_loss_ratio': 0.9997730135917664}
# ...
# Closed Position {'time': Timestamp('2022-06-18 09:41:00'), 'entry_price': 20393.4, 'type': 'long', 'take_profit': 20430.607797085497, 'stop_loss': 20389.607632502317, 'take_profit_ratio': 1.001824501901865, 'stop_loss_ratio': 0.9998140394687652, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 09:45:00'), 'entry_price': 20393.0, 'type': 'long', 'take_profit': 20427.281772430986, 'stop_loss': 20390.231567682327, 'take_profit_ratio': 1.0016810558736324, 'stop_loss_ratio': 0.9998642459511757}
# {'time': Timestamp('2022-06-18 09:45:00'), 'entry_price': 20393.0, 'type': 'long', 'take_profit': 20427.281772430986, 'stop_loss': 20390.231567682327, 'take_profit_ratio': 1.0016810558736324, 'stop_loss_ratio': 0.9998642459511757}
# Closed Position {'time': Timestamp('2022-06-18 09:45:00'), 'entry_price': 20393.0, 'type': 'long', 'take_profit': 20427.281772430986, 'stop_loss': 20390.231567682327, 'take_profit_ratio': 1.0016810558736324, 'stop_loss_ratio': 0.9998642459511757, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 09:47:00'), 'entry_price': 20384.0, 'type': 'long', 'take_profit': 20420.58216905594, 'stop_loss': 20380.504803180695, 'take_profit_ratio': 1.0017946511507034, 'stop_loss_ratio': 0.9998285323381424}
# {'time': Timestamp('2022-06-18 09:47:00'), 'entry_price': 20384.0, 'type': 'long', 'take_profit': 20420.58216905594, 'stop_loss': 20380.504803180695, 'take_profit_ratio': 1.0017946511507034, 'stop_loss_ratio': 0.9998285323381424}
# Closed Position {'time': Timestamp('2022-06-18 09:47:00'), 'entry_price': 20384.0, 'type': 'long', 'take_profit': 20420.58216905594, 'stop_loss': 20380.504803180695, 'take_profit_ratio': 1.0017946511507034, 'stop_loss_ratio': 0.9998285323381424, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 09:49:00'), 'entry_price': 20350.1, 'type': 'long', 'take_profit': 20385.571361465005, 'stop_loss': 20346.94324002251, 'take_profit_ratio': 1.0017430558800697, 'stop_loss_ratio': 0.9998448774218559}
# {'time': Timestamp('2022-06-18 09:49:00'), 'entry_price': 20350.1, 'type': 'long', 'take_profit': 20385.571361465005, 'stop_loss': 20346.94324002251, 'take_profit_ratio': 1.0017430558800697, 'stop_loss_ratio': 0.9998448774218559}
# Closed Position {'time': Timestamp('2022-06-18 09:49:00'), 'entry_price': 20350.1, 'type': 'long', 'take_profit': 20385.571361465005, 'stop_loss': 20346.94324002251, 'take_profit_ratio': 1.0017430558800697, 'stop_loss_ratio': 0.9998448774218559, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 09:51:00'), 'entry_price': 19740.2, 'type': 'long', 'take_profit': 19775.90386373699, 'stop_loss': 19736.87676005453, 'take_profit_ratio': 1.001808688044548, 'stop_loss_ratio': 0.9998316511511802}
# {'time': Timestamp('2022-06-18 09:51:00'), 'entry_price': 19740.2, 'type': 'long', 'take_profit': 19775.90386373699, 'stop_loss': 19736.87676005453, 'take_profit_ratio': 1.001808688044548, 'stop_loss_ratio': 0.9998316511511802}
# Closed Position {'time': Timestamp('2022-06-18 09:51:00'), 'entry_price': 19740.2, 'type': 'long', 'take_profit': 19775.90386373699, 'stop_loss': 19736.87676005453, 'take_profit_ratio': 1.001808688044548, 'stop_loss_ratio': 0.9998316511511802, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 09:53:00'), 'entry_price': 19371.6, 'type': 'long', 'take_profit': 19406.77119141966, 'stop_loss': 19368.151184872982, 'take_profit_ratio': 1.0018156059086323, 'stop_loss_ratio': 0.9998219653964042}
# {'time': Timestamp('2022-06-18 09:53:00'), 'entry_price': 19371.6, 'type': 'long', 'take_profit': 19406.77119141966, 'stop_loss': 19368.151184872982, 'take_profit_ratio': 1.0018156059086323, 'stop_loss_ratio': 0.9998219653964042}
# Closed Position {'time': Timestamp('2022-06-18 09:53:00'), 'entry_price': 19371.6, 'type': 'long', 'take_profit': 19406.77119141966, 'stop_loss': 19368.151184872982, 'take_profit_ratio': 1.0018156059086323, 'stop_loss_ratio': 0.9998219653964042, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 09:55:00'), 'entry_price': 19179.1, 'type': 'long', 'take_profit': 19213.610818273573, 'stop_loss': 19175.78291121766, 'take_profit_ratio': 1.0017993971705437, 'stop_loss_ratio': 0.9998270466923713}
# {'time': Timestamp('2022-06-18 09:55:00'), 'entry_price': 19179.1, 'type': 'long', 'take_profit': 19213.610818273573, 'stop_loss': 19175.78291121766, 'take_profit_ratio': 1.0017993971705437, 'stop_loss_ratio': 0.9998270466923713}
# Closed Position {'time': Timestamp('2022-06-18 09:55:00'), 'entry_price': 19179.1, 'type': 'long', 'take_profit': 19213.610818273573, 'stop_loss': 19175.78291121766, 'take_profit_ratio': 1.0017993971705437, 'stop_loss_ratio': 0.9998270466923713, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-18 09:57:00'), 'entry_price': 19458.4, 'type': 'long', 'take_profit': 19500.877643674612, 'stop_loss': 19453.280217219595, 'take_profit_ratio': 1.002182997763157, 'stop_loss_ratio': 0.9997368857264519}
# {'time': Timestamp('2022-06-18 09:57:00'), 'entry_price': 19458.4, 'type': 'long', 'take_profit': 19500.877643674612, 'stop_loss': 19453.280217219595, 'take_profit_ratio': 1.002182997763157, 'stop_loss_ratio': 0.9997368857264519}
# Closed Position {'time': Timestamp('2022-06-18 09:57:00'), 'entry_price': 19458.4, 'type': 'long', 'take_profit': 19500.877643674612, 'stop_loss': 19453.280217219595, 'take_profit_ratio': 1.002182997763157, 'stop_loss_ratio': 0.9997368857264519, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 09:59:00'), 'entry_price': 19419.8, 'type': 'long', 'take_profit': 19454.36499324441, 'stop_loss': 19415.936317496595, 'take_profit_ratio': 1.0017798840999603, 'stop_loss_ratio': 0.9998010441660881}
# {'time': Timestamp('2022-06-18 09:59:00'), 'entry_price': 19419.8, 'type': 'long', 'take_profit': 19454.36499324441, 'stop_loss': 19415.936317496595, 'take_profit_ratio': 1.0017798840999603, 'stop_loss_ratio': 0.9998010441660881}
# Closed Position {'time': Timestamp('2022-06-18 09:59:00'), 'entry_price': 19419.8, 'type': 'long', 'take_profit': 19454.36499324441, 'stop_loss': 19415.936317496595, 'take_profit_ratio': 1.0017798840999603, 'stop_loss_ratio': 0.9998010441660881, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-18 10:01:00'), 'entry_price': 19456.3, 'type': 'long', 'take_profit': 19500.640226078405, 'stop_loss': 19450.750033442677, 'take_profit_ratio': 1.0022789649665356, 'stop_loss_ratio': 0.9997147470712662}
# {'time': Timestamp('2022-06-18 10:01:00'), 'entry_price': 19456.3, 'type': 'long', 'take_profit': 19500.640226078405, 'stop_loss': 19450.750033442677, 'take_profit_ratio': 1.0022789649665356, 'stop_loss_ratio': 0.9997147470712662}
# Closed Position {'time': Timestamp('2022-06-18 10:01:00'), 'entry_price': 19456.3, 'type': 'long', 'take_profit': 19500.640226078405, 'stop_loss': 19450.750033442677, 'take_profit_ratio': 1.0022789649665356, 'stop_loss_ratio': 0.9997147470712662, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 10:03:00'), 'entry_price': 19329.3, 'type': 'long', 'take_profit': 19365.69484229274, 'stop_loss': 19324.227895453423, 'take_profit_ratio': 1.0018828846514225, 'stop_loss_ratio': 0.9997375950217247}
# {'time': Timestamp('2022-06-18 10:03:00'), 'entry_price': 19329.3, 'type': 'long', 'take_profit': 19365.69484229274, 'stop_loss': 19324.227895453423, 'take_profit_ratio': 1.0018828846514225, 'stop_loss_ratio': 0.9997375950217247}
# Closed Position {'time': Timestamp('2022-06-18 10:03:00'), 'entry_price': 19329.3, 'type': 'long', 'take_profit': 19365.69484229274, 'stop_loss': 19324.227895453423, 'take_profit_ratio': 1.0018828846514225, 'stop_loss_ratio': 0.9997375950217247, 'result': 'loss'}
#   2%|▋                                  | 2984/159320 [00:02<02:20, 1109.56it/s]
# Opened Position {'time': Timestamp('2022-06-18 10:05:00'), 'entry_price': 19281.8, 'type': 'long', 'take_profit': 19317.660057396442, 'stop_loss': 19276.433989083765, 'take_profit_ratio': 1.001859787851572, 'stop_loss_ratio': 0.9997217059135437}
# {'time': Timestamp('2022-06-18 10:05:00'), 'entry_price': 19281.8, 'type': 'long', 'take_profit': 19317.660057396442, 'stop_loss': 19276.433989083765, 'take_profit_ratio': 1.001859787851572, 'stop_loss_ratio': 0.9997217059135437}
# Closed Position {'time': Timestamp('2022-06-18 10:05:00'), 'entry_price': 19281.8, 'type': 'long', 'take_profit': 19317.660057396442, 'stop_loss': 19276.433989083765, 'take_profit_ratio': 1.001859787851572, 'stop_loss_ratio': 0.9997217059135437, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-18 10:07:00'), 'entry_price': 19350.6, 'type': 'long', 'take_profit': 19387.441083654016, 'stop_loss': 19346.754814121425, 'take_profit_ratio': 1.001903872936964, 'stop_loss_ratio': 0.9998012885451317}
# {'time': Timestamp('2022-06-18 10:07:00'), 'entry_price': 19350.6, 'type': 'long', 'take_profit': 19387.441083654016, 'stop_loss': 19346.754814121425, 'take_profit_ratio': 1.001903872936964, 'stop_loss_ratio': 0.9998012885451317}
# Closed Position {'time': Timestamp('2022-06-18 10:07:00'), 'entry_price': 19350.6, 'type': 'long', 'take_profit': 19387.441083654016, 'stop_loss': 19346.754814121425, 'take_profit_ratio': 1.001903872936964, 'stop_loss_ratio': 0.9998012885451317, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-18 10:09:00'), 'entry_price': 19456.0, 'type': 'long', 'take_profit': 19490.73394012451, 'stop_loss': 19452.412480163573, 'take_profit_ratio': 1.0017852559685707, 'stop_loss_ratio': 0.999815608561039}
# {'time': Timestamp('2022-06-18 10:09:00'), 'entry_price': 19456.0, 'type': 'long', 'take_profit': 19490.73394012451, 'stop_loss': 19452.412480163573, 'take_profit_ratio': 1.0017852559685707, 'stop_loss_ratio': 0.999815608561039}
# Closed Position {'time': Timestamp('2022-06-18 10:09:00'), 'entry_price': 19456.0, 'type': 'long', 'take_profit': 19490.73394012451, 'stop_loss': 19452.412480163573, 'take_profit_ratio': 1.0017852559685707, 'stop_loss_ratio': 0.999815608561039, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 10:11:00'), 'entry_price': 19430.0, 'type': 'long', 'take_profit': 19463.758785016835, 'stop_loss': 19427.016629487276, 'take_profit_ratio': 1.0017374567687511, 'stop_loss_ratio': 0.9998464554548263}
# {'time': Timestamp('2022-06-18 10:11:00'), 'entry_price': 19430.0, 'type': 'long', 'take_profit': 19463.758785016835, 'stop_loss': 19427.016629487276, 'take_profit_ratio': 1.0017374567687511, 'stop_loss_ratio': 0.9998464554548263}
# Closed Position {'time': Timestamp('2022-06-18 10:11:00'), 'entry_price': 19430.0, 'type': 'long', 'take_profit': 19463.758785016835, 'stop_loss': 19427.016629487276, 'take_profit_ratio': 1.0017374567687511, 'stop_loss_ratio': 0.9998464554548263, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-18 10:13:00'), 'entry_price': 19482.3, 'type': 'long', 'take_profit': 19518.124262516943, 'stop_loss': 19478.77463396117, 'take_profit_ratio': 1.0018388107419014, 'stop_loss_ratio': 0.9998190477490425}
# {'time': Timestamp('2022-06-18 10:13:00'), 'entry_price': 19482.3, 'type': 'long', 'take_profit': 19518.124262516943, 'stop_loss': 19478.77463396117, 'take_profit_ratio': 1.0018388107419014, 'stop_loss_ratio': 0.9998190477490425}
# Closed Position {'time': Timestamp('2022-06-18 10:13:00'), 'entry_price': 19482.3, 'type': 'long', 'take_profit': 19518.124262516943, 'stop_loss': 19478.77463396117, 'take_profit_ratio': 1.0018388107419014, 'stop_loss_ratio': 0.9998190477490425, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 10:15:00'), 'entry_price': 19412.4, 'type': 'long', 'take_profit': 19462.570303831995, 'stop_loss': 19405.45104732156, 'take_profit_ratio': 1.00258444622159, 'stop_loss_ratio': 0.9996420353651047}
# {'time': Timestamp('2022-06-18 10:15:00'), 'entry_price': 19412.4, 'type': 'long', 'take_profit': 19462.570303831995, 'stop_loss': 19405.45104732156, 'take_profit_ratio': 1.00258444622159, 'stop_loss_ratio': 0.9996420353651047}
# Closed Position {'time': Timestamp('2022-06-18 10:15:00'), 'entry_price': 19412.4, 'type': 'long', 'take_profit': 19462.570303831995, 'stop_loss': 19405.45104732156, 'take_profit_ratio': 1.00258444622159, 'stop_loss_ratio': 0.9996420353651047, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 10:17:00'), 'entry_price': 19286.9, 'type': 'long', 'take_profit': 19330.751065665485, 'stop_loss': 19281.935069570693, 'take_profit_ratio': 1.0022736191749573, 'stop_loss_ratio': 0.9997425749897957}
# {'time': Timestamp('2022-06-18 10:17:00'), 'entry_price': 19286.9, 'type': 'long', 'take_profit': 19330.751065665485, 'stop_loss': 19281.935069570693, 'take_profit_ratio': 1.0022736191749573, 'stop_loss_ratio': 0.9997425749897957}
# Closed Position {'time': Timestamp('2022-06-18 10:17:00'), 'entry_price': 19286.9, 'type': 'long', 'take_profit': 19330.751065665485, 'stop_loss': 19281.935069570693, 'take_profit_ratio': 1.0022736191749573, 'stop_loss_ratio': 0.9997425749897957, 'result': 'profit'}
# Opened Position {'time': Timestamp('2022-06-18 10:19:00'), 'entry_price': 19328.9, 'type': 'long', 'take_profit': 19366.597537472473, 'stop_loss': 19325.19904775992, 'take_profit_ratio': 1.0019503198564053, 'stop_loss_ratio': 0.9998085275292397}
# {'time': Timestamp('2022-06-18 10:19:00'), 'entry_price': 19328.9, 'type': 'long', 'take_profit': 19366.597537472473, 'stop_loss': 19325.19904775992, 'take_profit_ratio': 1.0019503198564053, 'stop_loss_ratio': 0.9998085275292397}
# Closed Position {'time': Timestamp('2022-06-18 10:19:00'), 'entry_price': 19328.9, 'type': 'long', 'take_profit': 19366.597537472473, 'stop_loss': 19325.19904775992, 'take_profit_ratio': 1.0019503198564053, 'stop_loss_ratio': 0.9998085275292397, 'result': 'loss'}
# Opened Position {'time': Timestamp('2022-06-18 10:21:00'), 'entry_price': 19292.4, 'type': 'long', 'take_profit': 19327.195471617582, 'stop_loss': 19288.88068009615, 'take_profit_ratio': 1.0018035843968391, 'stop_loss_ratio': 0.9998175799846649}
# {'time': Timestamp('2022-06-18 10:21:00'), 'entry_price': 19292.4, 'type': 'long', 'take_profit': 19327.195471617582, 'stop_loss': 19288.88068009615, 'take_profit_ratio': 1.0018035843968391, 'stop_loss_ratio': 0.9998175799846649}
# Closed Position {'time': Timestamp('2022-06-18 10:21:00'), 'entry_price': 19292.4, 'type': 'long', 'take_profit': 19327.195471617582, 'stop_loss': 19288.88068009615, 'take_profit_ratio': 1.0018035843968391, 'stop_loss_ratio': 0.9998175799846649, 'result': 'loss'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [111], in <cell line: 9>()
#      37 elif abs(output[2])>abs(output[3]):
#      38     open_position=True
# ---> 39     pos_dict["time"]=temp_f["OpenTime"].iloc[i]
#      40     pos_dict["entry_price"]=temp_f["Close"].iloc[i]
#      41     pos_dict["type"]="short"
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1626, in _iLocIndexer._getitem_axis(self, key, axis)
#    1623     raise TypeError("Cannot index by location index with a non-integer key")
#    1625 # validate the location
# -> 1626 self._validate_integer(key, axis)
#    1628 return self.obj._ixs(key, axis=axis)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1558, in _iLocIndexer._validate_integer(self, key, axis)
#    1556 len_axis = len(self.obj._get_axis(axis))
#    1557 if key >= len_axis or key < -len_axis:
# -> 1558     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
profit_margin
# Out:
# 1.190716304126599

# %%
res = pd.DataFrame(position_history)

# %%
res.groupby(["type","result"]).describe()
# Out:
#             entry_price                                                        \
#                   count          mean         std      min       25%      50%
# type result
# long loss         970.0  20838.167629  417.554603  19292.4  20532.95  20758.7
#      profit       284.0  20788.918310  417.382929  19179.1  20523.10  20775.0
#
#                                 take_profit                            \
#                    75%      max       count          mean         std
# type result
# long loss    21083.475  22114.0       970.0  20882.134829  419.439072
#      profit  21040.700  21946.1       284.0  20832.846699  419.562977
#
#                                                                     \
#                       min           25%          50%           75%
# type result
# long loss    19327.195472  20575.390691  20800.31332  21132.329982
#      profit  19213.610818  20561.808201  20815.40606  21082.667512
#
#                           stop_loss                                          \
#                       max     count          mean         std           min
# type result
# long loss    22152.855279     970.0  20833.084292  417.237153  19288.880680
#      profit  21993.302900     284.0  20783.865459  417.058929  19175.782911
#
#                                                                      \
#                       25%           50%           75%           max
# type result
# long loss    20528.096386  20752.262123  21077.108962  22109.773917
#      profit  20518.850438  20770.033102  21034.852122  21941.615542
#
#             take_profit_ratio                                          \
#                         count      mean       std       min       25%
# type result
# long loss               970.0  1.002109  0.000296  1.001623  1.001864
#      profit             284.0  1.002112  0.000294  1.001659  1.001868
#
#                                           stop_loss_ratio                      \
#                   50%       75%       max           count      mean       std
# type result
# long loss    1.002049  1.002307  1.003215           970.0  0.999756  0.000071
#      profit  1.002052  1.002312  1.003336           284.0  0.999757  0.000071
#
#
#                   min       25%       50%       75%       max
# type result
# long loss    0.999465  0.999712  0.999771  0.999812  1.000016
#      profit  0.999491  0.999709  0.999767  0.999810  1.000031

# %%
o1.shape
ohlc = o1[:4,:,:]
vol = o1[-1:,:,:]
ohlc = (ohlc-ohlc_mean)/ohlc_std
vol = (vol-vol_mean)/vol_std
on1 = np.concatenate((ohlc,vol),axis=0).reshape((1,*o1.shape))

# %%
torch.Tensor(on1).shape
# Out:
# torch.Size([1, 5, 32, 32])

# %%
dg =output.tolist()[0]

# %%
aa = dg[0]<dg[2]

# %%
aa
# Out:
# True
